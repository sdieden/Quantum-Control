# %%
import sys

from  sympy.physics.units.systems.si import units


sys.path.insert(0, '/Users/sam/PycharmProjects/Quantum-Control/NewModule')
# %matplotlib inline

# %%
#install lacking modules
#!{sys.executable} -m pip install pandas #sklearn (deprekated!) #sympy matplotlib arc

# %%
from arc import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
atom = Calcium40()
# Out:
# 4.0 0.0 0.0 0.0 0.0
# 4.0 1.0 0.0 1.0 15157.901
# 4.0 1.0 1.0 1.0 15210.063
# 4.0 1.0 2.0 1.0 15315.943
# 4.0 1.0 1.0 0.0 23652.304
# 5.0 0.0 1.0 1.0 31539.495
# 5.0 0.0 0.0 0.0 33317.264
# 5.0 1.0 0.0 1.0 36547.688
# 5.0 1.0 1.0 1.0 36554.749
# 5.0 1.0 2.0 1.0 36575.119
# 5.0 1.0 1.0 0.0 36731.615
# 4.0 2.0 2.0 0.0 37298.287
# 4.0 2.0 1.0 1.0 37748.197
# 4.0 2.0 2.0 1.0 37751.867
# 4.0 2.0 3.0 1.0 37757.449
# 5.0 2.0 2.0 0.0 42919.053
# 6.0 2.0 2.0 0.0 44989.83
# 7.0 2.0 2.0 0.0 46200.13
# 8.0 2.0 2.0 0.0 46948.98
# 9.0 2.0 2.0 0.0 47812.39
# 10.0 2.0 2.0 0.0 48083.41
# 11.0 2.0 2.0 0.0 48290.85
# 12.0 2.0 2.0 0.0 48451.73
# 13.0 2.0 2.0 0.0 48578.32
# 14.0 2.0 2.0 0.0 48678.97
# 15.0 2.0 2.0 0.0 48760.14
# 16.0 2.0 2.0 0.0 48827.05
# 17.0 2.0 2.0 0.0 48882.37
# 18.0 2.0 2.0 0.0 48928.79
# 19.0 2.0 2.0 0.0 48968.1
# 20.0 2.0 2.0 0.0 49001.66
# 20.0 3.0 3.0 0.0 49028.943
# 21.0 2.0 2.0 0.0 49030.55
# 21.0 3.0 3.0 0.0 49054.802
# 22.0 2.0 2.0 0.0 49055.62
# 22.0 3.0 3.0 0.0 49077.203
# 23.0 3.0 3.0 0.0 49096.736
# 23.0 2.0 2.0 0.0 49096.52
# 24.0 3.0 3.0 0.0 49113.869
# 26.0 2.0 2.0 0.0 49128.34
# 25.0 3.0 3.0 0.0 49128.981
# 27.0 2.0 2.0 0.0 49141.63
# 26.0 3.0 3.0 0.0 49142.378
# 28.0 2.0 2.0 0.0 49153.49
# 27.0 3.0 3.0 0.0 49154.309
# 29.0 2.0 2.0 0.0 49164.12
# 28.0 3.0 3.0 0.0 49164.979
# 30.0 2.0 2.0 0.0 49173.7
# 29.0 3.0 3.0 0.0 49174.563
# 31.0 2.0 2.0 0.0 49182.36
# 30.0 3.0 3.0 0.0 49183.202
# 32.0 2.0 2.0 0.0 49190.17
# 31.0 3.0 3.0 0.0 49191.014
# 33.0 2.0 2.0 0.0 49197.3
# 32.0 3.0 3.0 0.0 49198.105
# 34.0 2.0 2.0 0.0 49203.78
# 33.0 3.0 3.0 0.0 49204.558
# 35.0 2.0 2.0 0.0 49209.68
# 34.0 3.0 3.0 0.0 49210.45
# 36.0 2.0 2.0 0.0 49215.11
# 35.0 3.0 3.0 0.0 49215.842
# 37.0 2.0 2.0 0.0 49220.1
# 36.0 3.0 3.0 0.0 49220.79
# 38.0 2.0 2.0 0.0 49224.7
# 37.0 3.0 3.0 0.0 49225.341
# 39.0 2.0 2.0 0.0 49228.92
# 38.0 3.0 3.0 0.0 49229.537
# 40.0 2.0 2.0 0.0 49232.81
# 39.0 3.0 3.0 0.0 49233.414
# 41.0 2.0 2.0 0.0 49236.45
# 40.0 3.0 3.0 0.0 49237.002
# 42.0 2.0 2.0 0.0 49239.8
# 41.0 3.0 3.0 0.0 49240.331
# 43.0 2.0 2.0 0.0 49242.93
# 42.0 3.0 3.0 0.0 49243.425
# 44.0 2.0 2.0 0.0 49245.8
# 43.0 3.0 3.0 0.0 49246.304
# 45.0 2.0 2.0 0.0 49248.52
# 44.0 3.0 3.0 0.0 49248.989
# 46.0 2.0 2.0 0.0 49251.05
# 45.0 3.0 3.0 0.0 49251.496
# 47.0 2.0 2.0 0.0 49253.4
# 46.0 3.0 3.0 0.0 49253.842
# 48.0 2.0 2.0 0.0 49255.64
# 47.0 3.0 3.0 0.0 49256.04
# 49.0 2.0 2.0 0.0 49257.74
# 48.0 3.0 3.0 0.0 49258.1
# 50.0 2.0 2.0 0.0 49259.68
# 49.0 3.0 3.0 0.0 49260.036
# 51.0 2.0 2.0 0.0 49261.51
# 50.0 3.0 3.0 0.0 49261.857
# 52.0 2.0 2.0 0.0 49263.31
# 51.0 3.0 3.0 0.0 49263.571
# 53.0 2.0 2.0 0.0 49264.77
# 52.0 3.0 3.0 0.0 49265.187
# 54.0 2.0 2.0 0.0 49266.36
# 53.0 3.0 3.0 0.0 49266.713
# 55.0 2.0 2.0 0.0 49267.84
# 54.0 3.0 3.0 0.0 49268.155
# 56.0 2.0 2.0 0.0 49269.33
# 55.0 3.0 3.0 0.0 49269.518
# 57.0 2.0 2.0 0.0 49270.4
# 56.0 3.0 3.0 0.0 49270.808
# 58.0 2.0 2.0 0.0 49271.79
# 57.0 3.0 3.0 0.0 49272.032
# 59.0 2.0 2.0 0.0 49273.09
# 58.0 3.0 3.0 0.0 49273.193
# 60.0 2.0 2.0 0.0 49274.29
# 59.0 3.0 3.0 0.0 49274.295
# 61.0 2.0 2.0 0.0 49275.58
# 60.0 3.0 3.0 0.0 49275.342
# 62.0 2.0 2.0 0.0 49275.87
# 61.0 3.0 3.0 0.0 49276.338
# 62.0 3.0 3.0 0.0 49277.286
# 63.0 3.0 3.0 0.0 49278.19
# 64.0 3.0 3.0 0.0 49279.05
# 65.0 3.0 3.0 0.0 49279.872
# 66.0 3.0 3.0 0.0 49280.657
# 67.0 3.0 3.0 0.0 49281.406
# 68.0 3.0 3.0 0.0 49282.124
# 69.0 3.0 3.0 0.0 49282.809
# 70.0 3.0 3.0 0.0 49283.466
# 71.0 3.0 3.0 0.0 49284.095
# 72.0 3.0 3.0 0.0 49284.698
# 73.0 3.0 3.0 0.0 49285.277
# 74.0 3.0 3.0 0.0 49285.831
# 75.0 3.0 3.0 0.0 49286.364
# 76.0 3.0 3.0 0.0 49286.876
# 77.0 3.0 3.0 0.0 49287.369
# 78.0 3.0 3.0 0.0 49287.842
# 79.0 3.0 3.0 0.0 49288.297
# 80.0 3.0 3.0 0.0 49288.736
# 81.0 3.0 3.0 0.0 49289.158
# 82.0 3.0 3.0 0.0 49289.565
# 83.0 3.0 3.0 0.0 49289.957
# 84.0 3.0 3.0 0.0 49290.335
# 85.0 3.0 3.0 0.0 49290.701
# 86.0 3.0 3.0 0.0 49291.053
# 87.0 3.0 3.0 0.0 49291.393
# 88.0 3.0 3.0 0.0 49291.722
# 89.0 3.0 3.0 0.0 49292.04
# 90.0 3.0 3.0 0.0 49292.347
# 91.0 3.0 3.0 0.0 49292.643
# 92.0 3.0 3.0 0.0 49292.931
# 93.0 3.0 3.0 0.0 49293.209
# 94.0 3.0 3.0 0.0 49293.478
# 95.0 3.0 3.0 0.0 49293.74
# 96.0 3.0 3.0 0.0 49293.992
# 97.0 3.0 3.0 0.0 49294.237
# 98.0 3.0 3.0 0.0 49294.475
# 99.0 3.0 3.0 0.0 49294.705
# 100.0 3.0 3.0 0.0 49294.929
# 101.0 3.0 3.0 0.0 49295.146
# 102.0 3.0 3.0 0.0 49295.356
# 103.0 3.0 3.0 0.0 49295.561
# 104.0 3.0 3.0 0.0 49295.759
# 105.0 3.0 3.0 0.0 49295.952
# 106.0 3.0 3.0 0.0 49296.139
# 107.0 3.0 3.0 0.0 49296.321
# 108.0 3.0 3.0 0.0 49296.499
# 109.0 3.0 3.0 0.0 49296.671
# 110.0 3.0 3.0 0.0 49296.838
# 111.0 3.0 3.0 0.0 49297.002
# 112.0 3.0 3.0 0.0 49297.16
# 113.0 3.0 3.0 0.0 49297.315
# 114.0 3.0 3.0 0.0 49297.465
# 115.0 3.0 3.0 0.0 49297.612
# 116.0 3.0 3.0 0.0 49297.755
# 117.0 3.0 3.0 0.0 49297.894
# 118.0 3.0 3.0 0.0 49298.03
# 119.0 3.0 3.0 0.0 49298.161
# 120.0 3.0 3.0 0.0 49298.29
# 121.0 3.0 3.0 0.0 49298.416
# 122.0 3.0 3.0 0.0 49298.539
# 123.0 3.0 3.0 0.0 49298.659
# 124.0 3.0 3.0 0.0 49298.776
# 125.0 3.0 3.0 0.0 49298.889
# 126.0 3.0 3.0 0.0 49299.0
# 127.0 3.0 3.0 0.0 49299.11
# 128.0 3.0 3.0 0.0 49299.216
# 129.0 3.0 3.0 0.0 49299.319
# 130.0 3.0 3.0 0.0 49299.421
# 131.0 3.0 3.0 0.0 49299.52
# 132.0 3.0 3.0 0.0 49299.616
# 133.0 3.0 3.0 0.0 49299.71
# 134.0 3.0 3.0 0.0 49299.803
# 135.0 3.0 3.0 0.0 49299.893
# 136.0 3.0 3.0 0.0 49299.982
# 137.0 3.0 3.0 0.0 49300.068
# 138.0 3.0 3.0 0.0 49300.153
# 139.0 3.0 3.0 0.0 49300.235
# 140.0 3.0 3.0 0.0 49300.316
# 141.0 3.0 3.0 0.0 49300.396
# 142.0 3.0 3.0 0.0 49300.473
# 143.0 3.0 3.0 0.0 49300.549
# 144.0 3.0 3.0 0.0 49300.624
# 145.0 3.0 3.0 0.0 49300.696
# 146.0 3.0 3.0 0.0 49300.768
# 147.0 3.0 3.0 0.0 49300.838
# 148.0 3.0 3.0 0.0 49300.906
# 149.0 3.0 3.0 0.0 49300.973
# 150.0 3.0 3.0 0.0 49301.039

# %%
# Load parameters for Calcium


nmin = 33  # Minimum n
nmax = 37 # Maximum n
lmin = 0  # Minimum l
lmax = 8  # Maxmium l

# Plot Energy Levels of Cesium
levels = LevelPlot(atom)
levels.makeLevels(nmin, nmax, lmin, lmax, sList=[0])
levels.drawLevels()
levels.showPlot()
# Out:
# everything is fine
# quantum defect for 0= 2.3378085316415578
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 0= 2.3378160832740664
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 0= 2.33782295196654
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 0= 2.337829217653355
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0006688576340388701

# %%
atom.getQuantumDefect(35,6,6,0)
# Out:
# everything is fine
# quantum defect for 6= 0.0
# 0.0

# %%
## Stark Map

calc = StarkMap(Calcium40())

# Target state
n0 = 35
l0 = 1
j0 = 1
mj0 = 0
s0 = 0
state0 = np.array([n0,l0,j0,mj0])
# Define max/min n values in basis
nmin = n0 - 3
nmax = n0 + 3
# Maximum value of l to include (l~20 gives good convergence for states with l<5)
lmax = nmax - 1

# Initialise Basis States for Solver : progressOutput=True gives verbose output
calc.defineBasis(n0, l0, j0, mj0, nmin, nmax, lmax, progressOutput=True, s=s0)

Emin = 0.0  # Min E field (V/m)
Emax = 50.0e2  # Max E field (V/m)
N = 1001  # Number of Points

# Generate Stark Map
calc.diagonalise(np.linspace(Emin, Emax, N), progressOutput=True)

# Show Sark Map
calc.plotLevelDiagram(progressOutput=True, units='GHz', highlightState=True)
calc.ax.set_ylim(-3225,-2900 )
calc.showPlot(interactive=False)
# Return Polarizability of target state
#   print(
#    "%.5f MHz cm^2 / V^2 "
#    % calc.getPolarizability(showPlot=True, minStateContribution=0.9)
#)
# Out:
# 4.0 0.0 0.0 0.0 0.0
# 4.0 1.0 0.0 1.0 15157.901
# 4.0 1.0 1.0 1.0 15210.063
# 4.0 1.0 2.0 1.0 15315.943
# 4.0 1.0 1.0 0.0 23652.304
# 5.0 0.0 1.0 1.0 31539.495
# 5.0 0.0 0.0 0.0 33317.264
# 5.0 1.0 0.0 1.0 36547.688
# 5.0 1.0 1.0 1.0 36554.749
# 5.0 1.0 2.0 1.0 36575.119
# 5.0 1.0 1.0 0.0 36731.615
# 4.0 2.0 2.0 0.0 37298.287
# 4.0 2.0 1.0 1.0 37748.197
# 4.0 2.0 2.0 1.0 37751.867
# 4.0 2.0 3.0 1.0 37757.449
# 5.0 2.0 2.0 0.0 42919.053
# 6.0 2.0 2.0 0.0 44989.83
# 7.0 2.0 2.0 0.0 46200.13
# 8.0 2.0 2.0 0.0 46948.98
# 9.0 2.0 2.0 0.0 47812.39
# 10.0 2.0 2.0 0.0 48083.41
# 11.0 2.0 2.0 0.0 48290.85
# 12.0 2.0 2.0 0.0 48451.73
# 13.0 2.0 2.0 0.0 48578.32
# 14.0 2.0 2.0 0.0 48678.97
# 15.0 2.0 2.0 0.0 48760.14
# 16.0 2.0 2.0 0.0 48827.05
# 17.0 2.0 2.0 0.0 48882.37
# 18.0 2.0 2.0 0.0 48928.79
# 19.0 2.0 2.0 0.0 48968.1
# 20.0 2.0 2.0 0.0 49001.66
# 20.0 3.0 3.0 0.0 49028.943
# 21.0 2.0 2.0 0.0 49030.55
# 21.0 3.0 3.0 0.0 49054.802
# 22.0 2.0 2.0 0.0 49055.62
# 22.0 3.0 3.0 0.0 49077.203
# 23.0 3.0 3.0 0.0 49096.736
# 23.0 2.0 2.0 0.0 49096.52
# 24.0 3.0 3.0 0.0 49113.869
# 26.0 2.0 2.0 0.0 49128.34
# 25.0 3.0 3.0 0.0 49128.981
# 27.0 2.0 2.0 0.0 49141.63
# 26.0 3.0 3.0 0.0 49142.378
# 28.0 2.0 2.0 0.0 49153.49
# 27.0 3.0 3.0 0.0 49154.309
# 29.0 2.0 2.0 0.0 49164.12
# 28.0 3.0 3.0 0.0 49164.979
# 30.0 2.0 2.0 0.0 49173.7
# 29.0 3.0 3.0 0.0 49174.563
# 31.0 2.0 2.0 0.0 49182.36
# 30.0 3.0 3.0 0.0 49183.202
# 32.0 2.0 2.0 0.0 49190.17
# 31.0 3.0 3.0 0.0 49191.014
# 33.0 2.0 2.0 0.0 49197.3
# 32.0 3.0 3.0 0.0 49198.105
# 34.0 2.0 2.0 0.0 49203.78
# 33.0 3.0 3.0 0.0 49204.558
# 35.0 2.0 2.0 0.0 49209.68
# 34.0 3.0 3.0 0.0 49210.45
# 36.0 2.0 2.0 0.0 49215.11
# 35.0 3.0 3.0 0.0 49215.842
# 37.0 2.0 2.0 0.0 49220.1
# 36.0 3.0 3.0 0.0 49220.79
# 38.0 2.0 2.0 0.0 49224.7
# 37.0 3.0 3.0 0.0 49225.341
# 39.0 2.0 2.0 0.0 49228.92
# 38.0 3.0 3.0 0.0 49229.537
# 40.0 2.0 2.0 0.0 49232.81
# 39.0 3.0 3.0 0.0 49233.414
# 41.0 2.0 2.0 0.0 49236.45
# 40.0 3.0 3.0 0.0 49237.002
# 42.0 2.0 2.0 0.0 49239.8
# 41.0 3.0 3.0 0.0 49240.331
# 43.0 2.0 2.0 0.0 49242.93
# 42.0 3.0 3.0 0.0 49243.425
# 44.0 2.0 2.0 0.0 49245.8
# 43.0 3.0 3.0 0.0 49246.304
# 45.0 2.0 2.0 0.0 49248.52
# 44.0 3.0 3.0 0.0 49248.989
# 46.0 2.0 2.0 0.0 49251.05
# 45.0 3.0 3.0 0.0 49251.496
# 47.0 2.0 2.0 0.0 49253.4
# 46.0 3.0 3.0 0.0 49253.842
# 48.0 2.0 2.0 0.0 49255.64
# 47.0 3.0 3.0 0.0 49256.04
# 49.0 2.0 2.0 0.0 49257.74
# 48.0 3.0 3.0 0.0 49258.1
# 50.0 2.0 2.0 0.0 49259.68
# 49.0 3.0 3.0 0.0 49260.036
# 51.0 2.0 2.0 0.0 49261.51
# 50.0 3.0 3.0 0.0 49261.857
# 52.0 2.0 2.0 0.0 49263.31
# 51.0 3.0 3.0 0.0 49263.571
# 53.0 2.0 2.0 0.0 49264.77
# 52.0 3.0 3.0 0.0 49265.187
# 54.0 2.0 2.0 0.0 49266.36
# 53.0 3.0 3.0 0.0 49266.713
# 55.0 2.0 2.0 0.0 49267.84
# 54.0 3.0 3.0 0.0 49268.155
# 56.0 2.0 2.0 0.0 49269.33
# 55.0 3.0 3.0 0.0 49269.518
# 57.0 2.0 2.0 0.0 49270.4
# 56.0 3.0 3.0 0.0 49270.808
# 58.0 2.0 2.0 0.0 49271.79
# 57.0 3.0 3.0 0.0 49272.032
# 59.0 2.0 2.0 0.0 49273.09
# 58.0 3.0 3.0 0.0 49273.193
# 60.0 2.0 2.0 0.0 49274.29
# 59.0 3.0 3.0 0.0 49274.295
# 61.0 2.0 2.0 0.0 49275.58
# 60.0 3.0 3.0 0.0 49275.342
# 62.0 2.0 2.0 0.0 49275.87
# 61.0 3.0 3.0 0.0 49276.338
# 62.0 3.0 3.0 0.0 49277.286
# 63.0 3.0 3.0 0.0 49278.19
# 64.0 3.0 3.0 0.0 49279.05
# 65.0 3.0 3.0 0.0 49279.872
# 66.0 3.0 3.0 0.0 49280.657
# 67.0 3.0 3.0 0.0 49281.406
# 68.0 3.0 3.0 0.0 49282.124
# 69.0 3.0 3.0 0.0 49282.809
# 70.0 3.0 3.0 0.0 49283.466
# 71.0 3.0 3.0 0.0 49284.095
# 72.0 3.0 3.0 0.0 49284.698
# 73.0 3.0 3.0 0.0 49285.277
# 74.0 3.0 3.0 0.0 49285.831
# 75.0 3.0 3.0 0.0 49286.364
# 76.0 3.0 3.0 0.0 49286.876
# 77.0 3.0 3.0 0.0 49287.369
# 78.0 3.0 3.0 0.0 49287.842
# 79.0 3.0 3.0 0.0 49288.297
# 80.0 3.0 3.0 0.0 49288.736
# 81.0 3.0 3.0 0.0 49289.158
# 82.0 3.0 3.0 0.0 49289.565
# 83.0 3.0 3.0 0.0 49289.957
# 84.0 3.0 3.0 0.0 49290.335
# 85.0 3.0 3.0 0.0 49290.701
# 86.0 3.0 3.0 0.0 49291.053
# 87.0 3.0 3.0 0.0 49291.393
# 88.0 3.0 3.0 0.0 49291.722
# 89.0 3.0 3.0 0.0 49292.04
# 90.0 3.0 3.0 0.0 49292.347
# 91.0 3.0 3.0 0.0 49292.643
# 92.0 3.0 3.0 0.0 49292.931
# 93.0 3.0 3.0 0.0 49293.209
# 94.0 3.0 3.0 0.0 49293.478
# 95.0 3.0 3.0 0.0 49293.74
# 96.0 3.0 3.0 0.0 49293.992
# 97.0 3.0 3.0 0.0 49294.237
# 98.0 3.0 3.0 0.0 49294.475
# 99.0 3.0 3.0 0.0 49294.705
# 100.0 3.0 3.0 0.0 49294.929
# 101.0 3.0 3.0 0.0 49295.146
# 102.0 3.0 3.0 0.0 49295.356
# 103.0 3.0 3.0 0.0 49295.561
# 104.0 3.0 3.0 0.0 49295.759
# 105.0 3.0 3.0 0.0 49295.952
# 106.0 3.0 3.0 0.0 49296.139
# 107.0 3.0 3.0 0.0 49296.321
# 108.0 3.0 3.0 0.0 49296.499
# 109.0 3.0 3.0 0.0 49296.671
# 110.0 3.0 3.0 0.0 49296.838
# 111.0 3.0 3.0 0.0 49297.002
# 112.0 3.0 3.0 0.0 49297.16
# 113.0 3.0 3.0 0.0 49297.315
# 114.0 3.0 3.0 0.0 49297.465
# 115.0 3.0 3.0 0.0 49297.612
# 116.0 3.0 3.0 0.0 49297.755
# 117.0 3.0 3.0 0.0 49297.894
# 118.0 3.0 3.0 0.0 49298.03
# 119.0 3.0 3.0 0.0 49298.161
# 120.0 3.0 3.0 0.0 49298.29
# 121.0 3.0 3.0 0.0 49298.416
# 122.0 3.0 3.0 0.0 49298.539
# 123.0 3.0 3.0 0.0 49298.659
# 124.0 3.0 3.0 0.0 49298.776
# 125.0 3.0 3.0 0.0 49298.889
# 126.0 3.0 3.0 0.0 49299.0
# 127.0 3.0 3.0 0.0 49299.11
# 128.0 3.0 3.0 0.0 49299.216
# 129.0 3.0 3.0 0.0 49299.319
# 130.0 3.0 3.0 0.0 49299.421
# 131.0 3.0 3.0 0.0 49299.52
# 132.0 3.0 3.0 0.0 49299.616
# 133.0 3.0 3.0 0.0 49299.71
# 134.0 3.0 3.0 0.0 49299.803
# 135.0 3.0 3.0 0.0 49299.893
# 136.0 3.0 3.0 0.0 49299.982
# 137.0 3.0 3.0 0.0 49300.068
# 138.0 3.0 3.0 0.0 49300.153
# 139.0 3.0 3.0 0.0 49300.235
# 140.0 3.0 3.0 0.0 49300.316
# 141.0 3.0 3.0 0.0 49300.396
# 142.0 3.0 3.0 0.0 49300.473
# 143.0 3.0 3.0 0.0 49300.549
# 144.0 3.0 3.0 0.0 49300.624
# 145.0 3.0 3.0 0.0 49300.696
# 146.0 3.0 3.0 0.0 49300.768
# 147.0 3.0 3.0 0.0 49300.838
# 148.0 3.0 3.0 0.0 49300.906
# 149.0 3.0 3.0 0.0 49300.973
# 150.0 3.0 3.0 0.0 49301.039
# Found  207  states.
# Generating matrix...
# 0%<class 'int'>
# everything is fine
# quantum defect for 0= 2.3378002034368697
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.885305576656593
# 1%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8851977916437728
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378085316415578
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378160832740664
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.33782295196654
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.337829217653355
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8851977916437728
# 2%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 3= 0.09771207678813444
# 3%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# 4%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 5%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 6%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# 7%<class 'int'>
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# 8%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# 9%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0005227864514059222
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0004760681860739725
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.00043498075322356903
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# 10%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.00032956017432913284
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.0003001891875680238
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.00027435138454111015
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.0002515215765628773
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 11= 0.00023126577915475133
# 11%<class 'int'>
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# 0 <class 'int'>
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.0005227864514059222
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00021559119501664737
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.0004760681860739725
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00019643605809689015
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.00043498075322356903
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00017958025257010593
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00016468245047644855
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 11= 0.00036310379258979635
# everything is fine
# quantum defect for 12= 0.00015146054731942835
# 12%<class 'int'>
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# 0 <class 'int'>
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.00032956017432913284
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.0001456528240886071
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.0003001891875680238
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.00013276701104286985
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.00027435138454111015
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.0001214243079166556
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.0002515215765628773
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.0001113959843187599
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 11= 0.00023126577915475133
# everything is fine
# quantum defect for 12= 0.00023746117482606862
# everything is fine
# quantum defect for 13= 0.00010249295821695485
# 13%<class 'int'>
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# 0 <class 'int'>
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00021559119501664737
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 0.00010081834306540727
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00019643605809689015
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 9.191754660736189e-05
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00017958025257010593
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 8.407985130291795e-05
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00016468245047644855
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 7.714793567380749e-05
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 12= 0.00015146054731942835
# everything is fine
# quantum defect for 13= 0.00016036013321060527
# everything is fine
# quantum defect for 14= 7.099171915097499e-05
# 13%<class 'int'>
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# 0 <class 'int'>
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.0001456528240886071
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 7.171083241811616e-05
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.00013276701104286985
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 6.54209931068897e-05
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.0001214243079166556
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 5.9880238153433825e-05
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.0001113959843187599
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 5.497791667686955e-05
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 13= 0.00010249295821695485
# everything is fine
# quantum defect for 14= 0.00011097367272184231
# everything is fine
# quantum defect for 15= 5.0622514607996086e-05
# 14%<class 'int'>
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 0.00010081834306540727
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 5.240196544986047e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 9.191754660736189e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 4.786844874396684e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 8.407985130291795e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 4.38731377704667e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 7.714793567380749e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 4.0336690890692355e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 14= 7.099171915097499e-05
# everything is fine
# quantum defect for 15= 7.888436500571363e-05
# everything is fine
# quantum defect for 16= 3.71934702738742e-05
# 15%<class 'int'>
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 7.171083241811616e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 3.8382313659681344e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 6.54209931068897e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 3.505765827912664e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 5.9880238153433825e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 3.212632061039621e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 5.497791667686955e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 2.9530446776900015e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 15= 5.0622514607996086e-05
# everything is fine
# quantum defect for 16= 5.757018204579238e-05
# everything is fine
# quantum defect for 17= 2.722216069878702e-05
# 16%<class 'int'>
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 5.240196544986047e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 2.850158785604908e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 4.786844874396684e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 2.6026166022166675e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 4.38731377704667e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 2.3842476048030124e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 4.0336690890692355e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 2.19077114284736e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 16= 3.71934702738742e-05
# everything is fine
# quantum defect for 17= 4.2170626407687586e-05
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# 17%<class 'int'>
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 3.8382313659681344e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 2.1409429161066593e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 3.505765827912664e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 1.9541463118623767e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 3.212632061039621e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 1.7892717816602264e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 2.9530446776900015e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 1.643111323462018e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 17= 2.722216069878702e-05
# everything is fine
# quantum defect for 18= 3.132076887375261e-05
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# 18%<class 'int'>
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 2.850158785604908e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.623635149256388e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 2.6026166022166675e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.480987057972493e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 2.3842476048030124e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.3550027636318314e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 2.19077114284736e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# everything is fine
# quantum defect for 19= 2.3535591716193002e-05
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# 19%<class 'int'>
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 2.1409429161066593e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 1.3405053119052618e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 1.9541463118623767e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 1.2304225883310784e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 1.7892717816602264e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 1.1331346605581008e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 1.643111323462018e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# everything is fine
# quantum defect for 20= 1.7858996566514495e-05
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# 20%<class 'int'>
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.623635149256388e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 1.053192919258534e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.480987057972493e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 9.674325169717794e-06
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.3550027636318314e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 8.915845064556435e-06
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# everything is fine
# quantum defect for 21= 1.4656414031982422e-05
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# 20%<class 'int'>
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 1.3405053119052618e-05
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 8.34899373567042e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 1.2304225883310784e-05
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 7.67532716322841e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 1.1331346605581008e-05
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 7.079049729279467e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# everything is fine
# quantum defect for 22= 1.1506081581115721e-05
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# 21%<class 'int'>
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 1.053192919258534e-05
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 6.673322590627875e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 9.674325169717794e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 6.140184354832917e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 8.915845064556435e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 5.667879316951271e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# everything is fine
# quantum defect for 23= 9.113590240478515e-06
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# 22%<class 'int'>
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 8.34899373567042e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 5.373616792349575e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 7.67532716322841e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 4.948917038828558e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 7.079049729279467e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 4.572316867971679e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# everything is fine
# quantum defect for 24= 7.2778829574584965e-06
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# 23%<class 'int'>
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 6.673322590627875e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 4.357373720509208e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 6.140184354832917e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 4.01702790316208e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 5.667879316951271e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 3.7149087880049982e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# everything is fine
# quantum defect for 25= 5.854740142822265e-06
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# 24%<class 'int'>
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 5.373616792349575e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 3.553826098028452e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 4.948917038828558e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 3.2797597310855953e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 4.572316867971679e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 3.0361942523948352e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# everything is fine
# quantum defect for 26= 4.7425184249877936e-06
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# 25%<class 'int'>
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 4.357373720509208e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 2.915419323884137e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 4.01702790316208e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 2.6937072712252006e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 3.7149087880049982e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 2.4964164931278634e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# everything is fine
# quantum defect for 27= 3.863598823547363e-06
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# 26%<class 'int'>
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 3.553826098028452e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 2.404045463399333e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 3.2797597310855953e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 2.223999054130099e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 3.0361942523948352e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 2.063556184922949e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# everything is fine
# quantum defect for 28= 3.165685653686523e-06
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# 26%<class 'int'>
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 2.915419323884137e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 1.9909867520686455e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 2.6937072712252006e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 1.8443475293638724e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 2.4964164931278634e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 1.7134680549770927e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# everything is fine
# quantum defect for 29= 2.60698127746582e-06
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# 27%<class 'int'>
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 31= 1.7900724411010742e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 29= 2.404045463399333e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 31= 1.6556010054632646e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 29= 2.223999054130099e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 31= 1.535882442738952e-06
# everything is fine
# quantum defect for 30= 2.1559982299804686e-06
# everything is fine
# quantum defect for 29= 2.063556184922949e-06
# everything is fine
# ...
# 0 <class 'int'>
# everything is fine
# quantum defect for 19= 1.643111323462018e-05
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 19= 1.643111323462018e-05
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# everything is fine
# quantum defect for 19= 1.643111323462018e-05
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# 93%<class 'int'>
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# everything is fine
# quantum defect for 20= 1.2432510306367115e-05
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# 93%<class 'int'>
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# everything is fine
# quantum defect for 21= 1.0467809308794392e-05
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# 94%<class 'int'>
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# everything is fine
# quantum defect for 22= 8.242127367207743e-06
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# 94%<class 'int'>
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# everything is fine
# quantum defect for 23= 6.548994532083524e-06
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# 94%<class 'int'>
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# everything is fine
# quantum defect for 24= 5.247669348231977e-06
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# 94%<class 'int'>
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# everything is fine
# quantum defect for 25= 4.23694225346746e-06
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# 95%<class 'int'>
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# everything is fine
# quantum defect for 26= 3.44558458600061e-06
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# 95%<class 'int'>
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# everything is fine
# quantum defect for 27= 2.8188234691739064e-06
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# 95%<class 'int'>
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# everything is fine
# quantum defect for 28= 2.320124361758878e-06
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# 95%<class 'int'>
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# everything is fine
# quantum defect for 29= 1.9199924268404207e-06
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# 95%<class 'int'>
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# everything is fine
# quantum defect for 31= 1.332754034255449e-06
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# everything is fine
# quantum defect for 30= 1.5961791266575218e-06
# everything is fine
# quantum defect for 31= 1.246174688300525e-06
# 96%<class 'int'>
# everything is fine
# quantum defect for 31= 1.332754034255449e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 31= 1.332754034255449e-06
# everything is fine
# quantum defect for 32= 1.1179025443910989e-06
# everything is fine
# quantum defect for 31= 1.332754034255449e-06
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# everything is fine
# quantum defect for 31= 1.332754034255449e-06
# everything is fine
# quantum defect for 32= 1.0466534091788272e-06
# 96%<class 'int'>
# everything is fine
# quantum defect for 32= 1.1179025443910989e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 32= 1.1179025443910989e-06
# everything is fine
# quantum defect for 33= 9.411419038637403e-07
# everything is fine
# quantum defect for 32= 1.1179025443910989e-06
# everything is fine
# quantum defect for 31= 1.246174688300525e-06
# everything is fine
# quantum defect for 32= 1.1179025443910989e-06
# everything is fine
# quantum defect for 33= 8.823985772833818e-07
# 96%<class 'int'>
# everything is fine
# quantum defect for 33= 9.411419038637403e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 33= 9.411419038637403e-07
# everything is fine
# quantum defect for 34= 7.945262488568815e-07
# everything is fine
# quantum defect for 33= 9.411419038637403e-07
# everything is fine
# quantum defect for 32= 1.0466534091788272e-06
# everything is fine
# quantum defect for 33= 9.411419038637403e-07
# everything is fine
# quantum defect for 34= 7.460554349386206e-07
# 96%<class 'int'>
# everything is fine
# quantum defect for 34= 7.945262488568815e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 34= 7.945262488568815e-07
# everything is fine
# quantum defect for 35= 6.760682203551288e-07
# everything is fine
# quantum defect for 34= 7.945262488568815e-07
# everything is fine
# quantum defect for 33= 8.823985772833818e-07
# everything is fine
# quantum defect for 34= 7.945262488568815e-07
# everything is fine
# quantum defect for 35= 6.3486914944874e-07
# 96%<class 'int'>
# everything is fine
# quantum defect for 35= 6.760682203551288e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 35= 6.760682203551288e-07
# everything is fine
# quantum defect for 34= 7.460554349386206e-07
# everything is fine
# quantum defect for 35= 6.760682203551288e-07
# everything is fine
# quantum defect for 36= 5.431561109211001e-07
# 96%<class 'int'>
# everything is fine
# quantum defect for 0= 2.3378349489072785
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.885305576656593
# 97%<class 'int'>
# everything is fine
# quantum defect for 1= 1.885305576656593
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.885305576656593
# 97%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# 97%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# 97%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 97%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 97%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# 98%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002365339530380276
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# 98%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# 98%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# 98%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 11= 0.00023126577915475133
# 98%<class 'int'>
# everything is fine
# quantum defect for 11= 0.00023126577915475133
# 0 <class 'int'>
# everything is fine
# quantum defect for 11= 0.00023126577915475133
# everything is fine
# quantum defect for 12= 0.00015146054731942835
# 98%<class 'int'>
# everything is fine
# quantum defect for 12= 0.00015146054731942835
# 0 <class 'int'>
# everything is fine
# quantum defect for 12= 0.00015146054731942835
# everything is fine
# quantum defect for 13= 0.00010249295821695485
# 98%<class 'int'>
# everything is fine
# quantum defect for 13= 0.00010249295821695485
# 0 <class 'int'>
# everything is fine
# quantum defect for 13= 0.00010249295821695485
# everything is fine
# quantum defect for 14= 7.099171915097499e-05
# 98%<class 'int'>
# everything is fine
# quantum defect for 14= 7.099171915097499e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 14= 7.099171915097499e-05
# everything is fine
# quantum defect for 15= 5.0622514607996086e-05
# 98%<class 'int'>
# everything is fine
# quantum defect for 15= 5.0622514607996086e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 15= 5.0622514607996086e-05
# everything is fine
# quantum defect for 16= 3.71934702738742e-05
# 99%<class 'int'>
# everything is fine
# quantum defect for 16= 3.71934702738742e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 16= 3.71934702738742e-05
# everything is fine
# quantum defect for 17= 2.722216069878702e-05
# 99%<class 'int'>
# everything is fine
# quantum defect for 17= 2.722216069878702e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 17= 2.722216069878702e-05
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# 99%<class 'int'>
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 18= 2.0186436306627667e-05
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# 99%<class 'int'>
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 19= 1.5130083113296823e-05
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# 99%<class 'int'>
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# 0 <class 'int'>
# everything is fine
# quantum defect for 20= 1.143717654893827e-05
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 21= 9.698192417833899e-06
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 22= 7.641262410219825e-06
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 23= 6.075895827519621e-06
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 24= 4.872299338210538e-06
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 25= 3.937081712830434e-06
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 26= 3.2045384574751046e-06
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 27= 2.6240632475011485e-06
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 28= 2.1619791469356154e-06
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 29= 1.7910350284740745e-06
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 30= 1.4906686245205188e-06
# everything is fine
# quantum defect for 31= 1.246174688300525e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 31= 1.246174688300525e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 31= 1.246174688300525e-06
# everything is fine
# quantum defect for 32= 1.0466534091788272e-06
# 99%<class 'int'>
# everything is fine
# quantum defect for 32= 1.0466534091788272e-06
# 0 <class 'int'>
# everything is fine
# quantum defect for 32= 1.0466534091788272e-06
# everything is fine
# quantum defect for 33= 8.823985772833818e-07
# 99%<class 'int'>
# everything is fine
# quantum defect for 33= 8.823985772833818e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 33= 8.823985772833818e-07
# everything is fine
# quantum defect for 34= 7.460554349386206e-07
# 99%<class 'int'>
# everything is fine
# quantum defect for 34= 7.460554349386206e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 34= 7.460554349386206e-07
# everything is fine
# quantum defect for 35= 6.3486914944874e-07
# 99%<class 'int'>
# everything is fine
# quantum defect for 35= 6.3486914944874e-07
# 0 <class 'int'>
# everything is fine
# quantum defect for 35= 6.3486914944874e-07
# everything is fine
# quantum defect for 36= 5.431561109211001e-07
# 100%<class 'int'>
# everything is fine
# quantum defect for 36= 5.431561109211001e-07
# 0 <class 'int'>
#
#
# Finding eigenvectors...
# 100%
#
# plotting...
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 1= 1.8852687388969027
# 0

# %%
## Stark Map

calc = StarkMap(Calcium40())
#%matplotlib qt
# Target state
n0 = 35
l0 = 3
j0 = 3
mj0 = 0
s0 = 0
state0 = np.array([n0,l0,j0,mj0])
# Define max/min n values in basis
nmin = n0 - 5
nmax = n0 + 5
# Maximum value of l to include (l~20 gives good convergence for states with l<5)
lmax = 10

# Initialise Basis States for Solver : progressOutput=True gives verbose output
calc.defineBasis(n0, l0, j0, mj0, nmin, nmax, lmax, progressOutput=True, s=s0)

Emin = 0.0  # Min E field (V/m)
Emax = 25.0e2  # Max E field (V/m)
N = 1001  # Number of Points

# Generate Stark Map
calc.diagonalise(np.linspace(Emin, Emax, N), progressOutput=True)

# Show Sark Map
calc.plotLevelDiagram(progressOutput=True, units="eV", highlightState=True)
calc.ax.set_ylim(-0.012,-0.010 )
calc.showPlot(interactive=False)
# Return Polarizability of target state
#   print(
#    "%.5f MHz cm^2 / V^2 "
#    % calc.getPolarizability(showPlot=True, minStateContribution=0.9)
#)
# Out:
# 4.0 0.0 0.0 0.0 0.0
# 4.0 1.0 0.0 1.0 15157.901
# 4.0 1.0 1.0 1.0 15210.063
# 4.0 1.0 2.0 1.0 15315.943
# 4.0 1.0 1.0 0.0 23652.304
# 5.0 0.0 1.0 1.0 31539.495
# 5.0 0.0 0.0 0.0 33317.264
# 5.0 1.0 0.0 1.0 36547.688
# 5.0 1.0 1.0 1.0 36554.749
# 5.0 1.0 2.0 1.0 36575.119
# 5.0 1.0 1.0 0.0 36731.615
# 4.0 2.0 2.0 0.0 37298.287
# 4.0 2.0 1.0 1.0 37748.197
# 4.0 2.0 2.0 1.0 37751.867
# 4.0 2.0 3.0 1.0 37757.449
# 5.0 2.0 2.0 0.0 42919.053
# 6.0 2.0 2.0 0.0 44989.83
# 7.0 2.0 2.0 0.0 46200.13
# 8.0 2.0 2.0 0.0 46948.98
# 9.0 2.0 2.0 0.0 47812.39
# 10.0 2.0 2.0 0.0 48083.41
# 11.0 2.0 2.0 0.0 48290.85
# 12.0 2.0 2.0 0.0 48451.73
# 13.0 2.0 2.0 0.0 48578.32
# 14.0 2.0 2.0 0.0 48678.97
# 15.0 2.0 2.0 0.0 48760.14
# 16.0 2.0 2.0 0.0 48827.05
# 17.0 2.0 2.0 0.0 48882.37
# 18.0 2.0 2.0 0.0 48928.79
# 19.0 2.0 2.0 0.0 48968.1
# 20.0 2.0 2.0 0.0 49001.66
# 20.0 3.0 3.0 0.0 49028.943
# 21.0 2.0 2.0 0.0 49030.55
# 21.0 3.0 3.0 0.0 49054.802
# 22.0 2.0 2.0 0.0 49055.62
# 22.0 3.0 3.0 0.0 49077.203
# 23.0 3.0 3.0 0.0 49096.736
# 23.0 2.0 2.0 0.0 49096.52
# 24.0 3.0 3.0 0.0 49113.869
# 26.0 2.0 2.0 0.0 49128.34
# 25.0 3.0 3.0 0.0 49128.981
# 27.0 2.0 2.0 0.0 49141.63
# 26.0 3.0 3.0 0.0 49142.378
# 28.0 2.0 2.0 0.0 49153.49
# 27.0 3.0 3.0 0.0 49154.309
# 29.0 2.0 2.0 0.0 49164.12
# 28.0 3.0 3.0 0.0 49164.979
# 30.0 2.0 2.0 0.0 49173.7
# 29.0 3.0 3.0 0.0 49174.563
# 31.0 2.0 2.0 0.0 49182.36
# 30.0 3.0 3.0 0.0 49183.202
# 32.0 2.0 2.0 0.0 49190.17
# 31.0 3.0 3.0 0.0 49191.014
# 33.0 2.0 2.0 0.0 49197.3
# 32.0 3.0 3.0 0.0 49198.105
# 34.0 2.0 2.0 0.0 49203.78
# 33.0 3.0 3.0 0.0 49204.558
# 35.0 2.0 2.0 0.0 49209.68
# 34.0 3.0 3.0 0.0 49210.45
# 36.0 2.0 2.0 0.0 49215.11
# 35.0 3.0 3.0 0.0 49215.842
# 37.0 2.0 2.0 0.0 49220.1
# 36.0 3.0 3.0 0.0 49220.79
# 38.0 2.0 2.0 0.0 49224.7
# 37.0 3.0 3.0 0.0 49225.341
# 39.0 2.0 2.0 0.0 49228.92
# 38.0 3.0 3.0 0.0 49229.537
# 40.0 2.0 2.0 0.0 49232.81
# 39.0 3.0 3.0 0.0 49233.414
# 41.0 2.0 2.0 0.0 49236.45
# 40.0 3.0 3.0 0.0 49237.002
# 42.0 2.0 2.0 0.0 49239.8
# 41.0 3.0 3.0 0.0 49240.331
# 43.0 2.0 2.0 0.0 49242.93
# 42.0 3.0 3.0 0.0 49243.425
# 44.0 2.0 2.0 0.0 49245.8
# 43.0 3.0 3.0 0.0 49246.304
# 45.0 2.0 2.0 0.0 49248.52
# 44.0 3.0 3.0 0.0 49248.989
# 46.0 2.0 2.0 0.0 49251.05
# 45.0 3.0 3.0 0.0 49251.496
# 47.0 2.0 2.0 0.0 49253.4
# 46.0 3.0 3.0 0.0 49253.842
# 48.0 2.0 2.0 0.0 49255.64
# 47.0 3.0 3.0 0.0 49256.04
# 49.0 2.0 2.0 0.0 49257.74
# 48.0 3.0 3.0 0.0 49258.1
# 50.0 2.0 2.0 0.0 49259.68
# 49.0 3.0 3.0 0.0 49260.036
# 51.0 2.0 2.0 0.0 49261.51
# 50.0 3.0 3.0 0.0 49261.857
# 52.0 2.0 2.0 0.0 49263.31
# 51.0 3.0 3.0 0.0 49263.571
# 53.0 2.0 2.0 0.0 49264.77
# 52.0 3.0 3.0 0.0 49265.187
# 54.0 2.0 2.0 0.0 49266.36
# 53.0 3.0 3.0 0.0 49266.713
# 55.0 2.0 2.0 0.0 49267.84
# 54.0 3.0 3.0 0.0 49268.155
# 56.0 2.0 2.0 0.0 49269.33
# 55.0 3.0 3.0 0.0 49269.518
# 57.0 2.0 2.0 0.0 49270.4
# 56.0 3.0 3.0 0.0 49270.808
# 58.0 2.0 2.0 0.0 49271.79
# 57.0 3.0 3.0 0.0 49272.032
# 59.0 2.0 2.0 0.0 49273.09
# 58.0 3.0 3.0 0.0 49273.193
# 60.0 2.0 2.0 0.0 49274.29
# 59.0 3.0 3.0 0.0 49274.295
# 61.0 2.0 2.0 0.0 49275.58
# 60.0 3.0 3.0 0.0 49275.342
# 62.0 2.0 2.0 0.0 49275.87
# 61.0 3.0 3.0 0.0 49276.338
# 62.0 3.0 3.0 0.0 49277.286
# 63.0 3.0 3.0 0.0 49278.19
# 64.0 3.0 3.0 0.0 49279.05
# 65.0 3.0 3.0 0.0 49279.872
# 66.0 3.0 3.0 0.0 49280.657
# 67.0 3.0 3.0 0.0 49281.406
# 68.0 3.0 3.0 0.0 49282.124
# 69.0 3.0 3.0 0.0 49282.809
# 70.0 3.0 3.0 0.0 49283.466
# 71.0 3.0 3.0 0.0 49284.095
# 72.0 3.0 3.0 0.0 49284.698
# 73.0 3.0 3.0 0.0 49285.277
# 74.0 3.0 3.0 0.0 49285.831
# 75.0 3.0 3.0 0.0 49286.364
# 76.0 3.0 3.0 0.0 49286.876
# 77.0 3.0 3.0 0.0 49287.369
# 78.0 3.0 3.0 0.0 49287.842
# 79.0 3.0 3.0 0.0 49288.297
# 80.0 3.0 3.0 0.0 49288.736
# 81.0 3.0 3.0 0.0 49289.158
# 82.0 3.0 3.0 0.0 49289.565
# 83.0 3.0 3.0 0.0 49289.957
# 84.0 3.0 3.0 0.0 49290.335
# 85.0 3.0 3.0 0.0 49290.701
# 86.0 3.0 3.0 0.0 49291.053
# 87.0 3.0 3.0 0.0 49291.393
# 88.0 3.0 3.0 0.0 49291.722
# 89.0 3.0 3.0 0.0 49292.04
# 90.0 3.0 3.0 0.0 49292.347
# 91.0 3.0 3.0 0.0 49292.643
# 92.0 3.0 3.0 0.0 49292.931
# 93.0 3.0 3.0 0.0 49293.209
# 94.0 3.0 3.0 0.0 49293.478
# 95.0 3.0 3.0 0.0 49293.74
# 96.0 3.0 3.0 0.0 49293.992
# 97.0 3.0 3.0 0.0 49294.237
# 98.0 3.0 3.0 0.0 49294.475
# 99.0 3.0 3.0 0.0 49294.705
# 100.0 3.0 3.0 0.0 49294.929
# 101.0 3.0 3.0 0.0 49295.146
# 102.0 3.0 3.0 0.0 49295.356
# 103.0 3.0 3.0 0.0 49295.561
# 104.0 3.0 3.0 0.0 49295.759
# 105.0 3.0 3.0 0.0 49295.952
# 106.0 3.0 3.0 0.0 49296.139
# 107.0 3.0 3.0 0.0 49296.321
# 108.0 3.0 3.0 0.0 49296.499
# 109.0 3.0 3.0 0.0 49296.671
# 110.0 3.0 3.0 0.0 49296.838
# 111.0 3.0 3.0 0.0 49297.002
# 112.0 3.0 3.0 0.0 49297.16
# 113.0 3.0 3.0 0.0 49297.315
# 114.0 3.0 3.0 0.0 49297.465
# 115.0 3.0 3.0 0.0 49297.612
# 116.0 3.0 3.0 0.0 49297.755
# 117.0 3.0 3.0 0.0 49297.894
# 118.0 3.0 3.0 0.0 49298.03
# 119.0 3.0 3.0 0.0 49298.161
# 120.0 3.0 3.0 0.0 49298.29
# 121.0 3.0 3.0 0.0 49298.416
# 122.0 3.0 3.0 0.0 49298.539
# 123.0 3.0 3.0 0.0 49298.659
# 124.0 3.0 3.0 0.0 49298.776
# 125.0 3.0 3.0 0.0 49298.889
# 126.0 3.0 3.0 0.0 49299.0
# 127.0 3.0 3.0 0.0 49299.11
# 128.0 3.0 3.0 0.0 49299.216
# 129.0 3.0 3.0 0.0 49299.319
# 130.0 3.0 3.0 0.0 49299.421
# 131.0 3.0 3.0 0.0 49299.52
# 132.0 3.0 3.0 0.0 49299.616
# 133.0 3.0 3.0 0.0 49299.71
# 134.0 3.0 3.0 0.0 49299.803
# 135.0 3.0 3.0 0.0 49299.893
# 136.0 3.0 3.0 0.0 49299.982
# 137.0 3.0 3.0 0.0 49300.068
# 138.0 3.0 3.0 0.0 49300.153
# 139.0 3.0 3.0 0.0 49300.235
# 140.0 3.0 3.0 0.0 49300.316
# 141.0 3.0 3.0 0.0 49300.396
# 142.0 3.0 3.0 0.0 49300.473
# 143.0 3.0 3.0 0.0 49300.549
# 144.0 3.0 3.0 0.0 49300.624
# 145.0 3.0 3.0 0.0 49300.696
# 146.0 3.0 3.0 0.0 49300.768
# 147.0 3.0 3.0 0.0 49300.838
# 148.0 3.0 3.0 0.0 49300.906
# 149.0 3.0 3.0 0.0 49300.973
# 150.0 3.0 3.0 0.0 49301.039
# Found  110  states.
# Generating matrix...
# 1%<class 'int'>
# everything is fine
# quantum defect for 0= 2.337780756044139
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.337780756044139
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 3%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8851359971837816
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.3378085316415578
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.3378160832740664
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.33782295196654
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.337829217653355
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 1= 1.8851359971837816
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.8851359971837816
# 5%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 1= 1.8853362447074788
# everything is fine
# quantum defect for 3= 0.097803286889595
# 7%<class 'int'>
# everything is fine
# quantum defect for 3= 0.0972422281893886
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 3= 0.0972422281893886
# everything is fine
# quantum defect for 4= 0.0
# 8%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.097803286889595
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 10%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 12%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 14%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002348264787315746
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002348264787315746
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 15%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0012958471932631374
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 17%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0005227864514059222
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0004760681860739725
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.00043498075322356903
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0020579022341550737
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 19%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.0007081448341571604
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 20%<class 'int'>
# everything is fine
# quantum defect for 0= 2.337790988413688
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.337790988413688
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 22%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8851686422737761
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.3378085316415578
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.3378160832740664
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.33782295196654
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.337829217653355
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 1= 1.8851686422737761
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.8851686422737761
# 23%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 1= 1.8853362447074788
# everything is fine
# quantum defect for 3= 0.097803286889595
# 25%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09732854614548438
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 3= 0.09732854614548438
# everything is fine
# quantum defect for 4= 0.0
# 26%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.097803286889595
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 28%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 30%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 31%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002351431282084384
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002351431282084384
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 33%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.0023543044703639815
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.0023569195178234988
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.0023593064697871886
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002361491121139853
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0011659236282895132
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 34%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0010534051320615161
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0005761560210349303
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0009554424249838672
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0005227864514059222
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0008697273169056556
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0004760681860739725
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.000794377080565605
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.00043498075322356903
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0018515834353728072
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 36%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0016729040143705033
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0015173392868949595
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0013812238244578165
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0012615678381860404
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.0006374276377341663
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 37%<class 'int'>
# everything is fine
# quantum defect for 0= 2.3378002034368697
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.3378002034368697
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 38%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8851977916437728
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378085316415578
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378160832740664
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.33782295196654
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.337829217653355
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 1= 1.8851977916437728
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.8851977916437728
# 40%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 1= 1.885223932254908
# everything is fine
# quantum defect for 3= 0.09747903535745536
# everything is fine
# quantum defect for 1= 1.8852474685828
# everything is fine
# quantum defect for 3= 0.0975448340504449
# everything is fine
# quantum defect for 1= 1.8852687388969027
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 1= 1.8852880279041475
# everything is fine
# quantum defect for 3= 0.09766082249863253
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 1= 1.8853362447074788
# everything is fine
# quantum defect for 3= 0.097803286889595
# 41%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 3= 0.09740719073636661
# everything is fine
# quantum defect for 4= 0.0
# ...
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 89%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002363495718458739
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002363495718458739
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 89%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0007278460744009855
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 90%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0011559168349132717
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 91%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.0003986861587533347
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 91%<class 'int'>
# everything is fine
# quantum defect for 0= 2.3378349489072785
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.3378349489072785
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 92%<class 'int'>
# everything is fine
# quantum defect for 1= 1.885305576656593
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 1= 1.885305576656593
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.885305576656593
# 92%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 1= 1.8853362447074788
# everything is fine
# quantum defect for 3= 0.097803286889595
# 93%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 3= 0.09771207678813444
# everything is fine
# quantum defect for 4= 0.0
# 93%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.097803286889595
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 93%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 94%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 94%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002365339530380276
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002365339530380276
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 95%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0006688576340388701
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 95%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0010622434601352017
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 96%<class 'int'>
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.0003664920478127407
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 96%<class 'int'>
# everything is fine
# quantum defect for 0= 2.3378402048236637
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.3378402048236637
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 96%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8853215903799292
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 1= 1.8853215903799292
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.8853215903799292
# 97%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 1= 1.8853362447074788
# everything is fine
# quantum defect for 3= 0.097803286889595
# 97%<class 'int'>
# everything is fine
# quantum defect for 3= 0.09775943766794726
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 3= 0.09775943766794726
# everything is fine
# quantum defect for 4= 0.0
# 97%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 3= 0.097803286889595
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 97%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 98%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 98%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002367039313738437
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002367039313738437
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 98%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0006163511746091561
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 98%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0009788634959034949
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 99%<class 'int'>
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# 0 <class 'int'>
# everything is fine
# quantum defect for 10= 0.00033782308859988563
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 99%<class 'int'>
# everything is fine
# quantum defect for 0= 2.337845036549921
# 0 <class 'int'>
# everything is fine
# quantum defect for 0= 2.337845036549921
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 99%<class 'int'>
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 0 <class 'int'>
# everything is fine
# quantum defect for 1= 1.8853362447074788
# 99%<class 'int'>
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.097803286889595
# 99%<class 'int'>
# everything is fine
# quantum defect for 3= 0.097803286889595
# 0 <class 'int'>
# everything is fine
# quantum defect for 3= 0.097803286889595
# everything is fine
# quantum defect for 4= 0.0
# 99%<class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 4= 0.0
# everything is fine
# quantum defect for 5= 0.0
# 99%<class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 5= 0.0
# everything is fine
# quantum defect for 6= 0.0
# 99%<class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# 0 <class 'int'>
# everything is fine
# quantum defect for 6= 0.0
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 99%<class 'int'>
# everything is fine
# quantum defect for 7= 0.002368609696699128
# 0 <class 'int'>
# everything is fine
# quantum defect for 7= 0.002368609696699128
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 99%<class 'int'>
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# 0 <class 'int'>
# everything is fine
# quantum defect for 8= -0.0005694408042277116
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 99%<class 'int'>
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# 0 <class 'int'>
# everything is fine
# quantum defect for 9= 0.0009043701385781338
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 100%<class 'int'>
# everything is fine
# quantum defect for 10= 0.00031219857944440866
# 0 <class 'int'>
#
#
# Finding eigenvectors...
# 100%
#
# plotting...
# everything is fine
# quantum defect for 3= 0.09760524029668384
# everything is fine
# quantum defect for 3= 0.09760524029668384
# 0

# %%
a=calc.highlight[100]
# la fonction highlight contient la liste de tous les états qui sont calculés et modifie leur coef en fonction du champ electrique

MixingStates_Coef = []#list

MixingStates_Term = []#list

for i in range(len(a)):
    if a[i] > 10**-3 :
        #print('i=',i)
        #print("{}\t{}".format(calc.basisStates[i],a[i]))
        #print(len(a))
        #print(len(calc.basisStates))
        #print(calc.basisStates)

        MixingStates_Coef.append(a[i])
        MixingStates_Term.append(calc.basisStates[i])
        #print(calc.basisStates[i],'i')
        #print(calc.basisStates[i-1],'i-1')
        #print(calc.basisStates[i + 1], 'i+1')
    else :
        pass
#print('coef=',MixingStates_Coef)
# still need to check that highlight and basisStates are arranged the same way.

# histogramm of the mixingstates

n_bins = len(MixingStates_Coef)
MixingStates_Coef = np.array(MixingStates_Coef)
MixingStates_Term = np.array(MixingStates_Term)
#for i in range(len(MixingStates_Coef)):
#    MixingStates_Coef[i] = '%.2E' % Decimal(MixingStates_Coef[i])
# make data:
## separation of information for the term matrix
#x = []
#for i in range(len(MixingStates_Term)):
#    x.append(i+0.5)
# transform list of quantum numbers into terms
# in general terms are written such so ^2S+1L_J
def Term(n,l,j,s):
    first_quantum_number = n
    Spin_part = 2*s+1

    if l==0 :
        orbital = "S"
    elif l==1:
        orbital = "P"
    elif l==2:
        orbital = "D"
    elif l==3:
        orbital ="F"
    elif l==4:
        orbital = "G"
    elif l==5:
        orbital = "H"
    elif l==6:
        orbital = "I"
    elif l==7:
        orbital = "K"
    else :
        orbital = int(l)

    term = "{N}$^{S}{L}_{J}$"
    return term.format(N=int(first_quantum_number),J = int(j),L = orbital,S=int(Spin_part))
# now we rewrite the list of list as a list of terms
MixingStates_Term_new = []
#(MixingStates_Term)
for i in range(len(MixingStates_Term)):

    MixingStates_Term_new.append(Term(MixingStates_Term[i][0],MixingStates_Term[i][1],MixingStates_Term[i][2],MixingStates_Term[i][3]))

x = MixingStates_Term_new

y = MixingStates_Coef

# plot
fig, ax = plt.subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.5)
multiplier = 0
for coef in MixingStates_Coef:
    offset = multiplier
    rects = ax.bar(offset,coef ,width=1)
    ax.bar_label(rects,labels=[f"{coef:.3f}" for coef in rects.datavalues], padding=5, fontsize=8, rotation='vertical')
    multiplier+=1
#length of axes should be adjusted to the number of relevant states in the mixing state
ax.set(xlim=(-0.5, len(MixingStates_Coef)-0.5),
       ylim=(0, 1))
ax.set_ylabel('coefficient du mix')
ax.set_title(r'Mixing states of Stark Levels in $^{40}Ca$')
ax.tick_params(axis='x',pad=0)
plt.xticks(rotation = 90)
plt.show()

# %%
"""
NE FONCTIONNE PAS ENCORE

from PIL import Image

image = Image.open("stark.jpeg")
with open("image.pickle", "wb") as file:
    pickle.dump(image, file) 
"""
# Out:
# '\nNE FONCTIONNE PAS ENCORE\n\nfrom PIL import Image\n\nimage = Image.open("stark.jpeg")\nwith open("image.pickle", "wb") as file:\n    pickle.dump(image, file) \n'

# %%
"""
figx = pickle.load(open('image.pickle', 'rb'))
figx.show() # Show the figure, edit it, etc.!
"""
# Out:
# "\nfigx = pickle.load(open('image.pickle', 'rb'))\nfigx.show() # Show the figure, edit it, etc.!\n"

# %%
 
n = np.arange(6, 100, 1)

## a noter que ici c'est sans le calcium modifie, donc peu d'info.

# Plot Quantum Defects of Cs
fig, axes = plt.subplots(1, 1, figsize=(7, 5))

axes.plot(n, atom.getQuantumDefect(n, 0, 0), ".", label="$nS_{1}$")
axes.plot(n, atom.getQuantumDefect(n, 1, 1), ".", label="$nP_{2}$")
axes.plot(n, atom.getQuantumDefect(n, 2, 0), ".", label="$nD_{2}$")
axes.plot(n, atom.getQuantumDefect(n, 3, 1), ".", label="$nF_{4}$")
axes.legend(loc=0)
axes.set_xlabel("$n$")
axes.set_ylabel(r"Quantum Defect $\delta_{n\ell j}$")
axes.set_title("Ca Quantum Defects")
# Out:
# Text(0.5, 1.0, 'Ca Quantum Defects')

# %% [markdown]
#  Grace au papier de Gallagher, on peut essayer de trouver des quantum defect pour des l plus grands que ce que l'on a jusqu'à présent. Dans ce papier, il est presente une determination de l'energie par une perturbation. On a alors E = E_h - W, ou E_h est l'energie de l'atome d'hydrogene. La formule de l'energie d'atomes de Rydberg n'est pas utilise MAIS on peut simplement faire une equivalence entre ces deux formules pour determiner les QD pour les niveaux qui nous interesses.

# %% [markdown]
# $$ E = - \frac{1}{2n^2} - W_{pol,nl} = - \frac{1}{2(n-\delta_{nl})^2}  $$
# $$ W_{pol,nl}=-\frac{1}{2}k_d\alpha_d \langle r^{-4} \rangle _{nl} - \frac{1}{2}k_q \alpha_q \langle r^{-6} \rangle _{nl}$$
#
# On va utiliser les valeurs présentes pour le plus haut n que l'on ait a disposition en se disant que pour les niveaux qui nous interesses, sa valeur n'en sera pas trop eloignee (les valeurs ne changent pas enormement). Pour montrer que cela n'affecte pas trop, on pourrait faire un graphique des valeurs de k_d,... pour chaque n et faire une regression lineaire par exemple.

# %%
from sklearn.linear_model import LinearRegression
y = np.array([0.9780, 0.9797, 0.9812, 0.9824, 0.9835, 0.9845])
y = y.reshape(-1, 1)  # transforme en tableau (n, 1)

x = np.array([18, 19, 20, 21, 22, 23])
x = x.reshape(-1, 1)  # transforme en tableau (n, 1)


model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(17, 24)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')
plt.title("Linear Regression of k_q for l = 5")
plt.show()

# %%
y = np.array([0.9273, 0.9277, 0.9284, 0.9284, 0.9287, 0.9292])
y = y.reshape(-1, 1)  # transforme en tableau (n, 1)

x = np.array([18, 19, 20, 21, 22, 23])
x = x.reshape(-1, 1)  # transforme en tableau (n, 1)


model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(17, 24)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')
plt.title("Linear Regression of k_q for l = 6")
plt.show()

# %%
y = np.array([0.956528, 0.956518, 0.956500, 0.956437, 0.956453, 0.956423])
y = y.reshape(-1, 1)  # transforme en tableau (n, 1)

x = np.array([18, 19, 20, 21, 22, 23])
x = x.reshape(-1, 1)  # transforme en tableau (n, 1)


model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(17, 24)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')
plt.title("Linear Regression of k_d for l = 5")
plt.show()

# %%
y = np.array([0.972293, 0.972178, 0.972111, 0.972033, 0.971906, 0.971892])
y = y.reshape(-1, 1)  # transforme en tableau (n, 1)

x = np.array([18, 19, 20, 21, 22, 23])
x = x.reshape(-1, 1)  # transforme en tableau (n, 1)


model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(17, 24)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')
plt.title("Linear Regression of k_d for l = 6")
plt.show()

# %%
y = np.array([0.98680, 0.982543, 0.982437])
y = y.reshape(-1, 1)  # transforme en tableau (n, 1)

x = np.array([18, 19, 20])
x = x.reshape(-1, 1)  # transforme en tableau (n, 1)


model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(17, 24)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')
plt.title("Linear Regression of k_d for l = 7")
plt.show()

# %%
## on a un range pour les valeurs de a_d et a_q, donc faudra faire des tests pour voir ce qui semble ok ou pas. Voir faire plusieurs fois les calculs et voir tout ce qui pourrait se passer, a quel point un calcul est affecte par tel ou telle valeur choisi des coeff. (difference d'ordre de grandeur ?)

a_0 = 5.291772109*10**-11

k_d = np.array([0.956423,0.971892,0.982437]) # for respectively l=5,6,7
k_q = np.array([0.9845, 0.9292, 0.9376]) # for respectively l=5,6,7

# the values of alpha_d and alpha_q are bounded. 
alpha_d_low = 75.3*a_0**3
alpha_d_high = 76.9*a_0**3
alpha_q_low = 206*a_0**5
alpha_q_high = 1590*a_0**5

# %%
"""
From Chap 2 of Gallagher we can define the expectation values of powers of e-/nucleus distances
"""
def r4_expectation(n, ell):
    """
    Calcule la valeur de <1/r^4> en fonction de n et ell.
    """
    numerator = 3 * n**2 - ell * (ell + 1)
    denominator = (2 * n**5 * (ell + 3/2) * (ell + 1) * (ell + 1/2) * ell * (ell - 1/2))
    return numerator / denominator

def r6_expectation(n, ell):
    """
    Calcule la valeur de <1/r^6> en fonction de n et ell.
    """
    numerator = (35 * n**4 
                 - 5 * n**2 * (6 * ell * (ell + 1) - 5) 
                 + 3 * (ell + 2) * (ell + 1) * ell * (ell - 1))
    denominator = (8 * n**7 * (ell + 5/2) * (ell + 2) * (ell + 3/2) * 
                   (ell + 1) * (ell + 1/2) * ell * (ell - 1/2) * (ell - 1) * (ell - 3/2))
    return numerator / denominator

"""
noting that in gallagher, it's refered to two references where alpha_q is around 870. 
"""
"""def W_polarization_energy_shift (n, l, k_d, k_q,alpha_d = alpha_d_mid, alpha_q=alpha_q_mid):
    """
"""
    :param n: principal quantum number
    :param l: secondary quantum number
    :param alpha_d: alpha dipole
    :param alpha_q: alpha quandrupole   
    :param k_d: k dipole
    :param k_q: k quandrupole
    :param r**-4 : expectation values of power of distance electron-nucleus
    :return: value of the energy shift (real_E=E_hydrogen-W)
    """
"""
    x = -1/2*k_d*alpha_d*()-1/2*k_q*alpha_q*()
    print("polarization energy shift of",n,l,"=",x)
    return x"""
def print_n_l(n, l):
    return f"n={n}, l={l}"  # Return a formatted string instead of printing

# %%
x4 = []
y4 = []

nombre_quantique_principal_test = 35
for i in range(30,nombre_quantique_principal_test):

    for j in range(4,8):
        
        if j > 3 : 
            x4.append(print_n_l(i+1,j+1))
            y4.append(r4_expectation(i+1,j+1))
            
        else :
            pass
fig, ax = plt.subplots()
ax.plot(x4, y4, label="Expectation of r^-4")

ax.set_xlabel("Quantum States (n, l)")
ax.set_ylabel("Expectation Values")
ax.legend()
plt.xticks(rotation=90,fontsize=10)  # Rotate x-axis labels for readability if needed
plt.show()

# %%
x6 = []
y6 = []

nombre_quantique_principal_test = 35
for i in range(30,nombre_quantique_principal_test):

    for j in range(4,8):
        
        if j > 3 : 
            x6.append(print_n_l(i+1,j+1))
            y6.append(r6_expectation(i+1,j+1))
            
        else :
            pass
fig, ax = plt.subplots()
ax.plot(x6, y6, label="Expectation of r^-4")

ax.set_xlabel("Quantum States (n, l)")
ax.set_ylabel("Expectation Values")
ax.legend()
plt.xticks(rotation=90,fontsize=10)  # Rotate x-axis labels for readability if needed
plt.show()

# %%
import matplotlib.pyplot as plt

# Initialisation des listes pour stocker les valeurs de n, r4 et r6
n_values = range(44, 47)  # n entre 30 et 35
l_values = range(5, 8)    # l entre 5 et 7

# Initialisation des dictionnaires pour stocker les valeurs de <1/r^4> et <1/r^6> pour chaque l
r4_values = {l: [] for l in l_values}
r6_values = {l: [] for l in l_values}

# Calcul des valeurs pour chaque combinaison de n et l
for n in n_values:
    for l in l_values:
        r4 = r4_expectation(n, l)
        r6 = r6_expectation(n, l)
        r4_values[l].append(r4)
        r6_values[l].append(r6)

# Création du graphique
fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Tracé de <1/r^4> pour chaque valeur de l
for l in l_values:
    ax[0].plot(n_values, r4_values[l], 'o-', label=f'l={l}')
ax[0].set_ylabel("<1/r^4>")
ax[0].set_title("Évolution de <1/r^4> en fonction de n pour différents l")
ax[0].legend()

# Tracé de <1/r^6> pour chaque valeur de l
for l in l_values:
    ax[1].plot(n_values, r6_values[l], 'o-', label=f'l={l}')
ax[1].set_xlabel("Valeur de n")
ax[1].set_ylabel("<1/r^6>")
ax[1].set_title("Évolution de <1/r^6> en fonction de n pour différents l")
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# les valeurs de r4 et r6 sont correctes. J'ai testé pour n = 45 et l = 7 et on retombe exactement sur les valeurs calculees dans le code de Alisée.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constante a_0
a_0 = 1 # ua
# = 5.291772109 * 10**-11 # mètre

# Valeurs spécifiques de k_d et k_q pour l = 5, 6, 7
k_d_values = np.array([0.956423, 0.971892, 0.982437])
k_q_values = np.array([0.9845, 0.9292, 0.9376])

# Limites pour alpha_d et alpha_q
alpha_d_low = 75.3 * a_0**3
alpha_d_high = 76.9 * a_0**3
alpha_q_low = 206 * a_0**5
alpha_q_high = 1590 * a_0**5
alpha_d_mid = (alpha_d_low + alpha_d_high) / 2
alpha_q_mid = 870 * a_0**5

h_planck = 1 #u.a.#6.626e-34 #J*s

# Fonction pour le calcul du décalage d'énergie de polarisation
def W_polarization_energy_shift(n, l, alpha_d, alpha_q, k_d, k_q, units = 'MHz'): #m-1 ？
    """
    Calcule le décalage d'énergie de polarisation.
    
    :param n: principal quantum number
    :param l: secondary quantum number
    :param alpha_d: alpha dipole
    :param alpha_q: alpha quadrupole
    :param k_d: k dipole
    :param k_q: k quadrupole
    :param units: units
    :return: valeur du décalage d'énergie
    """
    # Calcul des valeurs de <1/r^4> et <1/r^6>
    r4 = r4_expectation(n, l)
    r6 = r6_expectation(n, l)

    
    # Calcul du décalage d'énergie
    x = -0.5 * k_d * alpha_d * r4 - 0.5 * k_q * alpha_q * r6
    x /= h_planck
    if units == 'MHz':
        x *= 6.5797*10**9
    else :
        pass

    return x

# Initialisation des listes pour stocker les résultats
l_values = [5, 6, 7]
n = 40
energy_shifts_low = []
energy_shifts_high = []
energy_shifts_mid = []

# Calcul des décalages d'énergie pour chaque l avec les valeurs limites de alpha_d et alpha_q
for i, l in enumerate(l_values):
    # Pour alpha_d et alpha_q bas
    shift_low = W_polarization_energy_shift(n, l, alpha_d_low, alpha_q_low, k_d_values[i], k_q_values[i])
    energy_shifts_low.append(shift_low)
    
    # Pour alpha_d et alpha_q haut
    shift_high = W_polarization_energy_shift(n, l, alpha_d_high, alpha_q_high, k_d_values[i], k_q_values[i])
    energy_shifts_high.append(shift_high)
    
    # Pour alpha_d et alpha_q mid
    shift_mid = W_polarization_energy_shift(n, l, alpha_d_mid, alpha_q_mid, k_d_values[i], k_q_values[i])
    energy_shifts_mid.append(shift_mid)
# Création du graphique
plt.figure(figsize=(10, 6))
plt.plot(l_values, energy_shifts_low, 'o-', label="Déplacement d'énergie (alpha bas)")
plt.plot(l_values, energy_shifts_high, 'o-', label="Déplacement d'énergie (alpha haut)")
plt.plot(l_values, energy_shifts_mid, 'o-', label="Déplacement d'énergie (alpha mid)")
plt.xlabel("Valeur de l")
plt.ylabel("Déplacement d'énergie de polarisation (W) (MHz)")
plt.title(f"Évolution du décalage d'énergie de polarisation pour n={n} et différentes valeurs de l")
plt.legend()
plt.grid(True)
plt.show()
print(energy_shifts_high)
print(energy_shifts_low)
print(energy_shifts_mid)
# Out:
# [np.float64(-1265.3922754419068), np.float64(-526.1173637349427), np.float64(-253.07759390688497)]
# [np.float64(-1156.0610353997592), np.float64(-499.1467105363781), np.float64(-243.58943823416234)]
# [np.float64(-1209.0062778890197), np.float64(-512.2999107141753), np.float64(-248.24599652414307)]

# %% [markdown]
# Les différences entre les valeurs low et high ne sont pas très grande mais peuvent quand même atteindre 150MHz pour le cas l=5.
# Pour voir si c'est un problème, on va regarder ce que calcule comme diff d'E W pour un cas l=5 que l'on peut calculer. Le plus haut niveau mesuré dans le NIST contenant un l=5 est le $14H^5$ qui a une énergie de -16744.283409999916 GHz par rapport à l'énergie d'ionisation.

# %%
atom.getEnergy(14,5,5,0) # = -16784.68647039

fifteenHwoQD = -16784.68647039 + 16744.283409999916
print(fifteenHwoQD)
# Out:
# -40.40306039008283

# %% [markdown]
# That calculation is done with a ∂_5=0. But the W calculated is around 25GHz. NIST has  a "level splittings (GHz) of 100 for that level". What does it mean in this case ?

# %%
import math
import pandas as pd
from IPython.display import display, HTML
## We define a function computing the W_low for a given n and l = 5,6,7 as it looks its the one that suits the most other code value.
def compute_all (n_array):
    '''

    :param n_array: liste des valeurs de n calculés

    :return: liste des valeurs des shifts d'énergies de polarisation par valeur de n cal
    '''
    # structure des données pour stocker par valeur de n calc
    results_by_n = []
    for n in n_array:
        energy_shifts_low = []
        for i, l in enumerate(l_values):

            shift_low = W_polarization_energy_shift(n, l, alpha_d_low, alpha_q_low, k_d_values[i],k_q_values[i])
            energy_shifts_low.append(shift_low)
        results_by_n[n] = energy_shifts_low

    return results_by_n


def compute_one_low(n,l):
    '''

    :param n: nombre qunatique n
    :param l: secondary nombre qunatique l=5,6,7

    :return: valeur du shift d'energie de polarisation pour n et l donné
    '''
    # structure des données pour stocker par valeur de n calc
    i = l-l_values[0]
    shift_low = W_polarization_energy_shift(n, l, alpha_d_low, alpha_q_low, k_d_values[i],k_q_values[i])

    return shift_low




Ry = 3.2898e15 #Hz
'''Pour une valeur de $nl$ donné, on a une valeur d'energie qui se calcule par la formule 
E = -1/2n^2-W_nl

def energy_w(n,l,a_d,a_q,k_d,k_q):
    E = -1/(2*n**2)-W_polarization_energy_shift(n,l,a_d,a_q,k_d,k_q)
    return E
###############VIEUX
globalement ce qu'on est capable de calculer c'est le terme delta_nl qui contient la somme en question avec delta0, delta2, delta4
'''
R_inf = 1.097373156850*10**7 #m^-1
"""
def quantum_defect_nl (n,l,k_d,k_q,alpha_d=alpha_d_mid,alpha_q=alpha_q_mid):
    print(n,l,k_d,k_q,alpha_d,alpha_q)
    #print('W=',1/((2*n**2)+W_polarization_energy_shift(n,l,alpha_d,alpha_q,k_d,k_q)**(-1)))
    #q = n - math.sqrt(R_inf*(1/(2*n**2)+W_polarization_energy_shift(n,l,alpha_d,alpha_q,k_d,k_q))**(-1))
    W = W_polarization_energy_shift(n,l,k_d,k_q,alpha_d,alpha_q)
    #print(W)
    frac = 1/(2*n**2)
    #print(frac)
    x = frac + W
    #print(x)
    x = 1/x
    #print(x)
    x = R_inf*x
    #print(x)
    x = math.sqrt(x)
    #print(x)
    
    
    q = n - x
    #print('q=',q)
     return q
 """
def delta_nl(en):

    deltatest = n - ( 1/ (np.sqrt( (en*10**6/Ry) + (1/n**2) )) ) #10**6 factor is used to convert in Hz

    return deltatest

def ritz_rydberg(n, delta_0, delta_2, delta_4):
    return delta_0 + delta_2 / (n - delta_0) ** 2 + delta_4 / (n - delta_0) ** 4

def create_quantum_table(y2):
    # Création des données
    data = []
    for i in range(len(y2)):
        data.append({
            'l (orbital)': 7+i,
            'W (MHz)': float(y2[i]),

            'delta_nl ': float(delta_nl(y2[i])),

        })

    # Création du DataFrame
    df = pd.DataFrame(data)

    # Style personnalisé pour un beau rendu
    style = """
    <style>
        table {width: 100%; border-collapse: collapse; margin: 25px 0; font-size: 0.9em;}
        th, td {padding: 12px 15px; text-align: center;}
        thead {background-color: #435B66; color: white;}
        tbody tr:nth-of-type(even) {background-color: #f3f3f3;}
        td {border-bottom: 1px solid #dddddd;}
        th:first-of-type {text-align: left;}
        td:first-of-type {text-align: left;}
    </style>
    """

    # Formatage des nombres en notation scientifique avec 6 décimales
    pd.options.display.float_format = '{:.6e}'.format

    # Affichage avec le style personnalisé
    display(HTML(style + df.to_html(index=False)))

    return df  # Retourne aussi le DataFrame pour d'éventuelles manipulations

# %%
import scipy.optimize as opt
ndata = list(range(30, 105))
# Dictionnaire pour stocker delta_nl pour chaque l
delta_by_l = {}
delta_by_l_neg = {}

# Boucle sur les valeurs de l
for l in l_values:
    delta_by_l[l] = []
    delta_by_l_neg[l]= []# Initialise une liste pour ce l

    # Boucle sur les valeurs de n
    for n in ndata:
        shift = 0
        shift = compute_one_low(n,l)
        delta_by_l[l].append(delta_nl(shift))
        delta_by_l_neg[l].append(-delta_nl(shift))


def plot_quantum_defects(delta_by_l, ndata, l_values):
    params_by_l = {}  # Stocker les paramètres optimisés pour chaque_l
    n_plots = len(l_values)
    n_cols = min(3, n_plots)  # Définition des colonnes pour un affichage compact
    n_rows = (n_plots + n_cols - 1) // n_cols  # Calcul du nombre de lignes

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 5*n_rows))

    # Gestion du cas où un seul subplot est généré
    if n_rows * n_cols > 1:
        axes = axes.flatten()
    else:
        axes = [axes]

    # Itération sur les valeurs de l
    for idx, l in enumerate(l_values):
        ax = axes[idx]

        # Vérification que l existe bien dans delta_by_l
        if l not in delta_by_l:
            continue

        # Récupération des défauts quantiques pour chaque n
        y2_values = np.array(delta_by_l[l])
        
        # Ajustement des paramètres
        p0 = [0.1, 1.0, 0.01]  # Valeurs initiales
       
        # Générer les valeurs de la courbe ajustée
        #n_fit = np.linspace(min(filtered_n), max(filtered_n), 100)
        #params, _ = opt.curve_fit(ritz_rydberg, filtered_n, delta_nl_values, p0=p0)
        params, _ = opt.curve_fit(ritz_rydberg, ndata, y2_values, p0=p0)
        n_fit = np.linspace(min(ndata), max(ndata), 100)
        delta_fit = ritz_rydberg(n_fit, *params)
  
        
        params_by_l[l] = params

        

        # Tracé des points
        ax.scatter(ndata, y2_values, marker='>', label=f'l={l}')
        ax.plot(n_fit, delta_fit, label=f"Fit l={l}", linestyle='--', color='blue')
                
        # Échelle logarithmique en y
        ax.set_yscale('log')

        # Labels et titre
        ax.set_xlabel('Principal quantum number n')
        ax.set_ylabel('Quantum defect')
        ax.set_title(f'Orbital quantum number l = {l}')
        fit_results_text="$\delta_0=${}\n$\delta_1=${}\n$\delta_2=${}".format(*params_by_l[l])
        ax.text(0.5, 0.5, fit_results_text, horizontalalignment='left', verticalalignment='center', transform=ax.transAxes)
        ax.legend()

        # Grille
        ax.grid(True, which="both", ls="-", alpha=0.2)

    # Suppression des subplots vides si nécessaire
    for idx in range(len(l_values), len(axes)):
        fig.delaxes(axes[idx])

    # Ajustement de la mise en page

    plt.tight_layout()
    return fig




fig = plot_quantum_defects(delta_by_l_neg, ndata, l_values)

plt.show()

def ritz_rydberg(n, delta_0, delta_2, delta_4):
    return delta_0 + delta_2 / (n - delta_0) ** 2 + delta_4 / (n - delta_0) ** 4
