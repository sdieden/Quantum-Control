# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as cst
import Wigner as Wigner
import scipy.linalg as linalg
import numpy as geek
import math
import scipy.special
#%matplotlib widget ##check pk ça marche pas
#update valeur qd dans tableau
from IPython.display import HTML
import json

# %%
#Constants
D4p = 0*1.02e-3
Wp4p = -1.02e-3#-6.8e-4 #-(2/3)*1.02e-3
pr24p = 21.75**2   

l = 7
K = l+1/2
W = 0
n = 20

s = 6
J = 0
for gamma in range(0,int(6+1)):
    J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
    J = J + J0

r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)

print(r6,r8)
for lp in range (int(l-2),int(l+3),2):
    #print(lp)
    Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
    C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
    W = W +(pr24p/Wp4p)*(C2*r6 + Wbar*C2*r8/(Wp4p)) #+(D4p*(1/3)*C2*r6)/Wp4p + Wbar*C2*r8/(Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(Wp4p**2))
    print(Wbar,Wp4p)
   
WHz = W*(4.3597447222071e-18)*10**(-6)/(6.626e-34) #put in MHz
print(W,WHz)
# Out:
# 7.378815428351031e-12 9.626834962232286e-15
# -8.5 -0.00102
# 4.5 -0.00102
# 21.5 -0.00102
# 6.029469386138588e-06 39672.42277984756

# %%
x = []
y1 = []
y2 = []
scale1 = []
scale2 = []
l = 12
for n in range(20,60):
    x.append(n)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    s = 6
    J = 0
    for gamma in range(0,int(6+1)):
        J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
        J = J + J0
    r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)
    y1.append(r6)
    y2.append(r8)
    
    #sc = 5e-4/(l**14)
    #scale2.append(sc)
    sc = 8e-14/(n**3)
    scale1.append(sc)
    
plt.figure()
#plt.scatter(x,y1,label='r6')
plt.scatter(x,y2,label='r8')
plt.plot(x,scale1,label='n-3')
#plt.plot(x,scale2, label='l-14')
plt.semilogy()
plt.legend()

# %%
#Everything
x = []
y1 = [] 
y2 = []
e1 = []
e2 = []
y3 = []
z1 = [] 
z2 = []
g1 = []
g2 = []
z3 = []
v3 = []
w3 = []
h1 = []
h2 = []
i1 = []
i2 = []
scale1 = []
scale2 = []
scale3 = []

#Constants
pr4s = 13
pr5s = 6.64
pr3d = 5.10
pr4d = 14.48
pr6s = 0.487
pr5d = 1.130
Wp4s = 0.115
Wp5s = -0.123
Wp3d = 0.052
Wp4d = -0.144
Wp6s = -0.207
Wp5d = -0.217
D3d = 2.77e-4*(5/40)
D4d = 8.75e-5*(5/40)
D5d = 3.97e-5*(5/40)
#quadrupole term
D4p = 1.02e-3
Wp4p = -(2/3)*1.02e-3
pr24p = 21.73**2 

Ws4p = -0.115 
D4p = 1.02e-3 
sr4p = 13

e = 1.6e-19
epsilon0 = 8.85e-12
a0 = 5.292e-11
pi = 3.14159
hp = 6.626e-34
Theta = 1.289*e*a0**2
Wd4p = -0.053
Wd4f = -0.248
dr4p = 5.10
dr4f = 1.87

pas = 1
l = 7 # L'abscisse de départ est 7
for k in range(0, 28): #l incrementation
    x.append(l)
    n = 35
    sc = 5e4/(l**3)
    scale1.append(sc)
    sc = 4e5/(l**5)
    scale2.append(sc)
    sc = 5e8/(l**14)
    scale3.append(sc)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    r4 = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    
    s = 6
    J = 0
    for gamma in range(0,int(6+1)):
        J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
        J = J + J0
    r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)
    
    #4p1/2
    W = 0
    K = l-1/2
    pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(2-l)*r6/Wp4s)
    pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(2-l)*r6/Wp5s)
    pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(2-l)*r6/Wp6s)
    pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) + (l+7)*r6/(9*Wp3d) - 2*r6*D3d*(l+7)/(15*Wp3d**2) )
    pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) + (l+7)*r6/(9*Wp4d) - 2*r6*D4d*(l+7)/(15*Wp4d**2) )
    pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) + (l+7)*r6/(9*Wp5d) - 2*r6*D5d*(l+7)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    pnlk = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d + W
    pnlkHz = pnlk*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    W = 0
    y1.append(np.absolute(pnlkHz)) 
    #if l == 12:
    #    print(1,pnlkHz)
    
    K = l+1/2
    Pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(l+3)*r6/Wp4s)
    Pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(l+3)*r6/Wp5s)
    Pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(l+3)*r6/Wp6s)
    Pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) - (l-6)*r6/(9*Wp3d) + 2*r6*D3d*(l-6)/(15*Wp3d**2) )
    Pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) - (l-6)*r6/(9*Wp4d) + 2*r6*D4d*(l-6)/(15*Wp4d**2) )
    Pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) - (l-6)*r6/(9*Wp5d) + 2*r6*D5d*(l-6)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    Pnlk = Pnlk4s + Pnlk5s + Pnlk3d + Pnlk4d + Pnlk6s + Pnlk5d + W
    PnlkHz = Pnlk*(4.360e-18)*10**(-6)/(6.626e-34)
    W = 0
    z1.append(np.absolute(PnlkHz))
    #if l == 12:
    #    print(2,PnlkHz)
    
    #4s1/2
    pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p - 2*(l+1)*D4p*r6/(9*Ws4p**2) ) #K=l-1/2
    pnlkHzs = pnlks*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y2.append(pnlkHzs)

    """if l == 11:
        print(11,pnlkHzs)
    if l == 12:
        print(12,pnlkHzs)
    """
    
    Pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p + 2*l*D4p*r6/(9*Ws4p**2) ) #K=l+1/2
    PnlkHzs = Pnlks*(4.360e-18)*10**(-6)/(6.626e-34)
    z2.append(PnlkHzs)

    """if l == 11:
        print(11,PnlkHzs)
    if l == 12:
        print(12,PnlkHzs)
    """
    
    #3d3/2
    #first order
    K = l-1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    e1.append(frequency)
    
    K = l+1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    g1.append(frequency)
    
    K = l+3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    h1.append(frequency)
    
    K = l-3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    i1.append(frequency)
    #second order
    pnlk4p = (dr4p/Wd4p)*( r4*(13*l+4)/75 + 6*(-l**2+2*l+1)*r6/(25*Wd4p) - D4p*(4*l+7)*r4/(75*Wd4p) +4*r6*D4p*(16*l**2-7*l-41)/(225*Wd4p**2) )/(2*l-1)
    pnlk4pHz = (pnlk4p)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l-1)/(25*(2*l-1)) )
    pnlk4fHz = (pnlk4f)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlkHzd = pnlk4pHz + pnlk4fHz #put in MHz
    e2.append(pnlkHzd)
    
    Pnlk4p = (dr4p/Wd4p)*( r4*(13*l+9)/75 + 6*(l**2+4*l+2)*r6/(25*Wd4p) - D4p*(4*l-3)*r4/(75*Wd4p) + (4*D4p*(-16*l**2-39*l+18)*r6)/(225*Wd4p**2) )/(2*l+3)
    Pnlk4pHz = Pnlk4p*(4.360e-18)*10**(-6)/(6.626e-34)
    Pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l+4)/(25*(2*l+3)) )
    Pnlk4fHz = Pnlk4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlkHzd = Pnlk4pHz + Pnlk4fHz
    g2.append(PnlkHzd)
    
    PnlK4p = (dr4p/Wd4p)*( r4*(9*l+10)/25 + 2*(9*l+10)*(l+3)*r6/(25*Wd4p) - (16*l+15)*r4*D4p/(75*Wd4p) - 4*(16*l+15)*(l+3)*r6*D4p/(75*Wd4p**2) )/(2*l+3)
    PnlK4pHz = PnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlK4f = (dr4f*r4/Wd4f)*( (11*l+15)/(25*(2*l+3)) )
    PnlK4fHz = PnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlKHzd = PnlK4pHz + PnlK4fHz
    h2.append(PnlKHzd)
    
    pnlK4p = (dr4p/Wd4p)*( r4*(9*l-1)/25 + 2*(9*l-1)*(2-l)*r6/(25*Wd4p) - (16*l+1)*D4p*r4/(75*Wd4p) - 4*(16*l+1)*(2-l)*r6*D4p/(75*Wd4p**2) )/(2*l-1)
    pnlK4pHz = pnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlK4f = (dr4f*r4/Wd4f)*( (11*l-4)/(25*(2*l-1)) )
    pnlK4fHz = pnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlKHzd = pnlK4pHz + pnlK4fHz
    i2.append(pnlKHzd)
    
    l += pas

y3 = np.add(e1,e2)
z3 = np.add(g1,g2)
v3 = np.add(h1,h2)
w3 = np.add(i1,i2)
#print(y3,z3,v3,w3)
y1 = np.array(y1)
y2 = np.array(y2)
y3 = np.array(y3)
z1 = np.array(z1)
z2 = np.array(z2)
z3 = np.array(z3)
v3 = np.array(v3)
w3 = np.array(w3)
#print(y1,z1) #4p1/2
for i in range(len(y2)):

    print('n°:',7+i,';W',y2[i],'∆=',y2[i]-z2[i]) #4s1/2
#K splittings


y3 = np.array(y3) #positive argument for log
y3 = -y3  
y2 = np.array(y2) #positive argument for log
y2 = -y2

z3 = np.array(z3) #positive argument for log
z3 = -z3  
z2 = np.array(z2) #positive argument for log
z2 = -z2

plt.figure()
plt.scatter(x,y2,label='4s1/2',color='b')
#plt.scatter(x,y1,label='4p1/2',color='purple')
#plt.scatter(x,y3,label='3d3/2',color='olive')
plt.scatter(x,z2,label='4s1/2',marker='x',color='b')
#plt.errorbar(x,y2,yerr=np.abs(y2-z2))
#plt.scatter(x,z1,label='4p1/2',marker='x',color='purple')
#plt.scatter(x,z3,label='3d3/2',marker='x',color='olive')
#plt.scatter(x,v3,label='3d3/2',marker='+',color='olive')
#plt.scatter(x,w3,label='3d3/2',marker='v',color='olive')
#plt.plot(x,scale1,color='k') #,label='l^-3'
plt.plot(x,scale2,color='cyan') #,label='l^-5'
#plt.plot(x,scale3,color='purple')
plt.semilogy()

#plt.legend()

#plt.title('Total energy shift, in absolute value, with respect to \n the orbital quantum number l2 (n2=45)') #K=l-1/2 in dots and K=l+1/2 in plus
plt.xlabel('Orbital quantum number l2')
plt.ylabel('Energy shift [MHz]')
plt.savefig('total_energy_shift.png')
# Out:
# n°: 7 ;W -358.27941049845606 ∆= 0.2865879837436296
# n°: 8 ;W -191.97220997435602 ∆= 0.10090364492691606
# n°: 9 ;W -109.80288950414057 ∆= 0.04003274471462248
# n°: 10 ;W -66.25716429946186 ∆= 0.01743892264033775
# n°: 11 ;W -41.78992549228003 ∆= 0.008189601210816022
# n°: 12 ;W -27.352204641027846 ∆= 0.004090692251690342
# n°: 13 ;W -18.472642420641275 ∆= 0.0021512276061343982
# n°: 14 ;W -12.81500796643865 ∆= 0.0011816227231413734
# n°: 15 ;W -9.098681422845509 ∆= 0.0006736386356607227
# n°: 16 ;W -6.591944173853114 ∆= 0.0003965542381747511
# n°: 17 ;W -4.861308801134059 ∆= 0.00024003090030610963
# n°: 18 ;W -3.641677188175468 ∆= 0.0001488605297872425
# n°: 19 ;W -2.7663082512176382 ∆= 9.430363426998767e-05
# n°: 20 ;W -2.1276676640286585 ∆= 6.0866901856027056e-05
# n°: 21 ;W -1.6548323761599426 ∆= 3.993418447678643e-05
# n°: 22 ;W -1.3000718377998208 ∆= 2.6578750329742107e-05
# n°: 23 ;W -1.0306713845088764 ∆= 1.791217299373926e-05
# ...

# %%
Ry = 3.2898e15 #Hz
n = 35
E = 358.2794e6
delta_nl=[]
def delta_nl(en):

    deltatest = n - ( 1/ (np.sqrt( (en*10**6/Ry) + (1/n**2) )) ) #10**6 factor is used to convert in Hz

    return deltatest


deltanl = []
deltanl2 = []
larray = []
for i in range(len(y2)):
    deltanl.append((n - ( 1/ (np.sqrt( (y2[i]*10**6/Ry) + (1/n**2) )) ))) #Hz à
    deltanl2.append((n - ( 1/ (np.sqrt( (z2[i]*10**6/Ry) + (1/n**2) )) )))
    larray.append(i+7)

# %%
import pandas as pd
from IPython.display import display, HTML

def create_quantum_table(y2, z2):
    # Création des données
    data = []
    for i in range(len(y2)):
        data.append({
            'l (orbital)': 7+i,
            'W (MHz)': float(y2[i]),
            'Δ (MHz)': float(y2[i]-z2[i]),
            'delta_nl ': float(delta_nl(y2[i])),
            'delta_nl2 ': float(delta_nl(z2[i])),
        })
    
    # Création du DataFrame
    df = pd.DataFrame(data)
    
    # Style personnalisé pour un beau rendu
    style = """
    <style>
        table {width: 100%; border-collapse: collapse; margin: 25px 0; font-size: 0.9em;}
        th, td {padding: 12px 15px; text-align: center;}
        thead {background-color: #435B66; color: white;}
        tbody tr:nth-of-type(even) {background-color: #f3f3f3;}
        td {border-bottom: 1px solid #dddddd;}
        th:first-of-type {text-align: left;}
        td:first-of-type {text-align: left;}
    </style>
    """
    
    # Formatage des nombres en notation scientifique avec 6 décimales
    pd.options.display.float_format = '{:.6e}'.format
    
    # Affichage avec le style personnalisé
    display(HTML(style + df.to_html(index=False)))
    
    return df  # Retourne aussi le DataFrame pour d'éventuelles manipulations

# Utilisation :
df = create_quantum_table(y2, z2)

plt.figure()
plt.scatter(larray,deltanl,marker='>', label='K=1/2')
plt.scatter(larray,deltanl2,marker='<', label='K=-1/2')
plt.semilogy()
plt.xlabel('Orbital quantum number l2')
plt.ylabel('quantum defect')
# Out:
#     <style>
#         table {width: 100%; border-collapse: collapse; margin: 25px 0; font-size: 0.9em;}
#         th, td {padding: 12px 15px; text-align: center;}
#         thead {background-color: #435B66; color: white;}
#         tbody tr:nth-of-type(even) {background-color: #f3f3f3;}
#         td {border-bottom: 1px solid #dddddd;}
#         th:first-of-type {text-align: left;}
#         td:first-of-type {text-align: left;}
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>l (orbital)</th>
#       <th>W (MHz)</th>
#       <th>Δ (MHz)</th>
#       <th>delta_nl</th>
#       <th>delta_nl2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>7</td>
#       <td>3.582794e+02</td>
#       <td>-2.865880e-01</td>
#       <td>2.334442e-03</td>
#       <td>2.336309e-03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.919722e+02</td>
#       <td>-1.009036e-01</td>
#       <td>1.250892e-03</td>
# ...

# %%
import pandas as pd
from IPython.display import display, HTML
##The goal is to compute all QD for high l in the range for n=[30,50], l must go from 7 (lower bound for this code) to n-1 (upper bound)
##we only use the case where the 2nd valence electron is in the 4s state (must check if enough)
def r6(n,l):
    x = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    return x
def r4(n,l):
    x = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    return x
def compute_energy(n_min, n_max, l_lower, pas=1):
    # Structures de données pour stocker les résultats par n
    results_by_n = {
        'y2': {},  # Pour K=l-1/2
        'z2': {}   # Pour K=l+1/2
    }



    for n in range(n_min, n_max + 1):
        l_upper = n - 1
        l = l_lower
        x = []
        y2_current_n = []  # Stockage temporaire pour y2 du n courant
        z2_current_n = []  # Stockage temporaire pour z2 du n courant

        for k in range(l_lower, l_upper+1):
            x.append(k)

            # Calcul de J
            s = 6
            J = 0
            for gamma in range(0, int(6+1)):
                J0 = (-1)**(s-gamma) * (
                    scipy.special.binom(s,gamma) *
                    scipy.special.binom(n-l-1+gamma,s) /
                    scipy.special.binom(2*l+1+s-gamma,s+1)
                )
                J = J + J0

            # Calculs pour K=l-1/2
            pnlks = (sr4p/Ws4p) * (r4(n,k)/3 + r6(n,k)/Ws4p - 2*(k+1)*D4p*r6(n,k)/(9*Ws4p**2))
            pnlkHzs = pnlks * (4.360e-18) * 10**(-6)/(6.626e-34)  # Conversion en MHz
            y2_current_n.append(pnlkHzs)

            # Calculs pour K=l+1/2
            Pnlks = (sr4p/Ws4p) * (r4(n,k)/3 + r6(n,k)/Ws4p + 2*k*D4p*r6(n,k)/(9*Ws4p**2))
            PnlkHzs = Pnlks * (4.360e-18) * 10**(-6)/(6.626e-34)  # Conversion en MHz
            z2_current_n.append(PnlkHzs)

            k += pas
        # Stockage des résultats pour le n courant
        results_by_n['y2'][n] = y2_current_n
        results_by_n['z2'][n] = z2_current_n

    return results_by_n


def create_quantum_table_complete(results_by_n):
    """
    Crée un tableau pour chaque valeur de n dans les résultats

    Args:
        results_by_n: dictionnaire contenant les résultats y2 et z2 par n

    Returns:
        dict: Dictionnaire de DataFrames, un pour chaque valeur de n
    """
    all_tables = {}
    if 'delta_nl' not in results_by_n:
        results['delta_nl'] = {}
        results['delta_nl2'] = {}

    for n in results_by_n['y2'].keys():
        y2_values = results_by_n['y2'][n]
        z2_values = results_by_n['z2'][n]

        # Création des données pour ce n
        data = []
        delta_nl_values = []  # liste pour stocker les valeurs de delta_nl
        delta_nl2_values = []
        for i in range(len(y2_values)):
            l_value = 7 + i  # Correspondance entre l et l_lower = 7

            # Calcul des valeurs de delta_nl
            delta_nl_y = float(delta_nl(y2_values[i]))
            delta_nl_z = float(delta_nl(z2_values[i]))

            # Stockage des valeurs pour une utilisation ultérieure
            delta_nl_values.append(delta_nl_y)
            delta_nl2_values.append(delta_nl_z)
            data.append({
                'n': n,
                'l (orbital)': l_value,
                'W (MHz)': float(y2_values[i]),
                'Δ (MHz)': float(y2_values[i]-z2_values[i]),
                'delta_nl ': delta_nl_y,
                'delta_nl2': delta_nl_z,
                'Δ∂': float(delta_nl_y-delta_nl_z),
            })

        results['delta_nl'][n] = delta_nl_values
        results['delta_nl2'][n] = delta_nl2_values
        # Création du DataFrame pour ce n
        df = pd.DataFrame(data)

        # Style personnalisé
        style = """
        <style>
            table {width: 100%; border-collapse: collapse; margin: 25px 0; font-size: 0.9em;}
            th, td {padding: 12px 15px; text-align: center;}
            thead {background-color: #435B66; color: white;}
            tbody tr:nth-of-type(even) {background-color: #f3f3f3;}
            td {border-bottom: 1px solid #dddddd;}
            th:first-of-type {text-align: left;}
            td:first-of-type {text-align: left;}
        </style>
        """

        # Formatage des nombres en notation scientifique avec 6 décimales
        pd.options.display.float_format = '{:.6e}'.format

        # Affichage avec le style personnalisé
        print(f"\nTable pour n = {n}")
        display(HTML(style + df.to_html(index=False)))

        # Stockage du DataFrame dans le dictionnaire
        all_tables[n] = df

    return all_tables, results



"""
plt.figure()
plt.scatter(larray,deltanl,marker='>', label='K=1/2')
plt.scatter(larray,deltanl2,marker='<', label='K=-1/2')
plt.semilogy()
plt.xlabel('Orbital quantum number l2')
plt.ylabel('quantum defect')
"""
# Out:
# "\nplt.figure()\nplt.scatter(larray,deltanl,marker='>', label='K=1/2')\nplt.scatter(larray,deltanl2,marker='<', label='K=-1/2')\nplt.semilogy()\nplt.xlabel('Orbital quantum number l2')\nplt.ylabel('quantum defect')\n"

# %%
 # Exemple d'utilisation :
results = compute_energy(n_min=30, n_max=50, l_lower=7)
tables, delta_list = create_quantum_table_complete(results)
# Out:
# Table pour n = 30
#         <style>
#             table {width: 100%; border-collapse: collapse; margin: 25px 0; font-size: 0.9em;}
#             th, td {padding: 12px 15px; text-align: center;}
#             thead {background-color: #435B66; color: white;}
#             tbody tr:nth-of-type(even) {background-color: #f3f3f3;}
#             td {border-bottom: 1px solid #dddddd;}
#             th:first-of-type {text-align: left;}
#             td:first-of-type {text-align: left;}
#         </style>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>n</th>
#       <th>l (orbital)</th>
#       <th>W (MHz)</th>
#       <th>Δ (MHz)</th>
#       <th>delta_nl</th>
#       <th>delta_nl2</th>
#       <th>Δ∂</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30</td>
#       <td>7</td>
#       <td>-5.658922e+02</td>
#       <td>4.485637e-01</td>
#       <td>-1.075435e-02</td>
#       <td>-1.076288e-02</td>
# ...

# %%
def plot_quantum_defects(results_by_n):
    """
    Crée des subplots pour chaque valeur de n montrant les défauts quantiques
    pour K=1/2 et K=-1/2 en fonction de l
    """
    n_values = list(results_by_n['y2'].keys())
    n_plots = len(n_values)

    # Calcul du nombre de lignes et colonnes optimal pour les subplots
    n_cols = min(3, n_plots)  # Maximum 3 colonnes
    n_rows = (n_plots + n_cols - 1) // n_cols

    # Création de la figure avec des subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 5*n_rows))
    if n_rows * n_cols > 1:
        axes = axes.flatten()
    else:
        axes = [axes]

    # Pour chaque valeur de n
    for idx, n in enumerate(n_values):
        ax = axes[idx]

        # Récupération des données
        y2_values = np.array(results_by_n['y2'][n])*(-1)
        z2_values = np.array(results_by_n['z2'][n])*(-1)

        # Création du tableau des l
        l_values = np.array([7 + i for i in range(len(y2_values))])

        # Calcul des défauts quantiques
        deltanl = [delta_nl(val*10**6) for val in y2_values]
        deltanl2 = [delta_nl(val*10**6) for val in z2_values]

        # Tracé des points
        ax.scatter(l_values, deltanl, marker='>', label='K=1/2')
        ax.scatter(l_values, deltanl2, marker='<', label='K=-1/2')

        # Échelle logarithmique en y
        ax.set_yscale('log')

        # Labels et titre
        ax.set_xlabel('Orbital quantum number l')
        ax.set_ylabel('Quantum defect')
        ax.set_title(f'n = {n}')
        ax.legend()

        # Grille
        ax.grid(True, which="both", ls="-", alpha=0.2)

    # Suppression des subplots vides si nécessaire
    for idx in range(len(n_values), len(axes)):
        fig.delaxes(axes[idx])

    # Ajustement de la mise en page
    plt.tight_layout()
    return fig



#fig = plot_quantum_defects(results)
#plt.show()

# %%
l_lower = 7
ndata = list(range(30, 51))  # Liste des valeurs de n de 30 à 50

# Dictionnaire pour stocker delta_nl pour chaque l
delta_by_l = {}

# Boucle sur les valeurs de l
for l in range(l_lower, max(ndata)):  # max(ndata) = 50
    delta_by_l[l] = []  # Initialise une liste pour ce l

    # Boucle sur les valeurs de n
    for n in ndata:
        #print('n', n)

        if l > n - 1:  # Vérifie que l ne dépasse pas n-1
            #print('skip l:', l, 'for n:', n)
            delta_by_l[l].append(None)  # Ajouter None pour garder une structure cohérente
            continue  # Passe au n suivant sans arrêter la boucle

        #print('l', l)

        if n in delta_list['delta_nl']:  # Vérifie que n existe dans delta_list
            delta_by_l[l].append(delta_list['delta_nl'][n][l - l_lower])  # Ajouter delta_nl pour ce n
        else:
            #print('ici')
            delta_by_l[l].append(None)  # Ajouter None si le QD ne peut pas être calculé


"""
###test
for l in range(l_lower, max(ndata)):
    delta_by_l[l] = [] #initialisation d'une liste pour cette valeur de l

    for n in ndata:
        if l == int:

            if l <= n - 1:
                delta_by_l[l].append(delta_list['delta_nl'][n][l - l_lower])
            elif l > n - 1:
                break
        else:
            print('error : l must be an integer, value = ', l)

          """
def ritz_rydberg(n, delta_0, delta_2, delta_4):
    return delta_0 + delta_2 / (n - delta_0) ** 2 + delta_4 / (n - delta_0) ** 4

# %%
import scipy.optimize as opt
# Sélectionner un l particulier pour la régression (ex: l = 10)
l_value = 10  # Choisir une valeur de l
n_values = np.array(ndata)  # Liste des n

# Extraire les valeurs de delta_nl sans None
delta_nl_values = np.array([delta_by_l[l_value][i] for i in range(len(ndata)) if delta_by_l[l_value][i] is not None])
filtered_n = np.array([n_values[i] for i in range(len(ndata)) if delta_by_l[l_value][i] is not None])

#valeur positive pour le graphique

delta_nl_values = - delta_nl_values
# Estimation initiale des paramètres (peut être ajustée)
p0 = [0.1, 1.0, 0.01]  # Valeurs initiales pour delta_0, delta_2, delta_4

# Ajustement par moindres carrés non linéaires
params, covariance = opt.curve_fit(ritz_rydberg, filtered_n, delta_nl_values, p0=p0)

# Extraire les paramètres optimisés
delta_0_opt, delta_2_opt, delta_4_opt = params

print(f"Paramètres optimisés pour l={l_value} :")
print(f"delta_0 = {delta_0_opt:.6f}")
print(f"delta_2 = {delta_2_opt:.6f}")
print(f"delta_4 = {delta_4_opt:.6f}")

# Générer les valeurs de la courbe ajustée
n_fit = np.linspace(min(filtered_n), max(filtered_n), 100)  # Plus de points pour lisser la courbe
delta_fit = ritz_rydberg(n_fit, delta_0_opt, delta_2_opt, delta_4_opt)

# Affichage
plt.figure(figsize=(8,5))
plt.scatter(filtered_n, delta_nl_values, label="Données expérimentales", color='red', marker='o')
plt.plot(n_fit, delta_fit, label="Fit Ritz-Rydberg", linestyle='--', color='blue')
plt.xlabel("n")
plt.ylabel("delta_nl")
plt.legend()
plt.title(f"Ajustement de la formule de Ritz-Rydberg pour l = {l_value}")
plt.show()
# Out:
# Paramètres optimisés pour l=10 :
# delta_0 = -0.000046
# delta_2 = 0.395781
# delta_4 = 231.046429

# %%
params_by_l = {}  # Stocker les paramètres optimisés pour chaque l

for l_value in range(7, max(ndata)):  # Tester pour chaque l
    delta_nl_values = np.array([delta_by_l[l_value][i] for i in range(len(ndata)) if delta_by_l[l_value][i] is not None])
    filtered_n = np.array([n_values[i] for i in range(len(ndata)) if delta_by_l[l_value][i] is not None])

    if len(filtered_n) > 3:  # Vérifier qu'on a assez de points pour un fit
        params, _ = opt.curve_fit(ritz_rydberg, filtered_n, delta_nl_values, p0=[0.1, 1.0, 0.01])
        params_by_l[l_value] = params

# Affichage des résultats
"""
for l, param in params_by_l.items():
    print(f"l={l} : delta_0={param[0]:.6f}, delta_2={param[1]:.6f}, delta_4={param[2]:.6f}")
"""

# Définir le nombre de sous-graphiques par ligne et colonne
num_l_values = len(delta_by_l.keys())
num_cols = 4  # Nombre de colonnes de sous-graphiques
num_rows = (num_l_values // num_cols)   # Calcul dynamique du nombre de lignes

# Création de la figure avec plusieurs sous-graphiques
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, num_rows * 5))
axes = axes.flatten()  # Convertir en liste pour faciliter l'accès

plot_index = 0  # Index du subplot

# Boucle sur toutes les valeurs de l
for l_value in sorted(delta_by_l.keys()):  # Trier les l pour un affichage structuré
    if l_value in delta_by_l:
        # Extraire les valeurs de delta_nl sans None
        filtered_n = np.array([n for i, n in enumerate(ndata) if delta_by_l[l_value][i] is not None])
        delta_nl_values = np.array([delta_by_l[l_value][i] for i in range(len(ndata)) if delta_by_l[l_value][i] is not None])
        delta_nl_values = - delta_nl_values
        # Vérifier qu'on a assez de points pour un fit
        if len(filtered_n) > 3:
            try:
                # Ajustement des paramètres
                p0 = [0.1, 1.0, 0.01]  # Valeurs initiales
                params, _ = opt.curve_fit(ritz_rydberg, filtered_n, delta_nl_values, p0=p0)
                params_by_l[l_value] = params

                # Générer les valeurs de la courbe ajustée
                n_fit = np.linspace(min(filtered_n), max(filtered_n), 100)
                delta_fit = ritz_rydberg(n_fit, *params)

                # Ajout du graphique dans le subplot correspondant
              #  ax = axes[plot_index]
              #  ax.scatter(filtered_n, delta_nl_values, label=f"Données l={l_value}", color='red', marker='o')
              #  ax.plot(n_fit, delta_fit, label=f"Fit l={l_value}", linestyle='--', color='blue')
              #  ax.set_xlabel("n")
              #  ax.set_ylabel("delta_nl")
              #  ax.legend()
              #  ax.set_title(f"Ajustement pour l = {l_value}")


                plot_index += 1  # Passer au prochain subplot

            except RuntimeError:
                print(f"⚠️ Fit échoué pour l={l_value}, essaye un autre p0")

# Ajustement de l'affichage
#plt.tight_layout()
#plt.show()

# %%
#modif
Ry = 3.2898e15 #Hz
n = 35
E = 358.2794e6
delta = n - ( 1/ (np.sqrt( (E/Ry) + (1/n**2) )) )
print(delta)
#delta12 = 0.00015307182760437854
#delta11 = 0.00023968624945425177
#deltaE = -Ry * ( 1/(n-delta12)**2 - 1/(n-delta11)**2)
#print(deltaE*1e-6) #in MHz
# Out:
# 0.002334441674186394

# %%
#Glukhov
n=35
delta_0=2.34348
delta_2=-1.28187
delta_4=50.7498
deltanl = delta_0 + delta_2/(n-delta_0)**2+(delta_4/(n-delta_0)**4)
print(deltanl)
delta_0=1.88558
delta_2=-3.2409
delta_4=-23.75
deltanl = delta_0 + delta_2/(n-delta_0)**2+(delta_4/(n-delta_0)**4)
print(deltanl)
# Out:
# 2.3423226233863685
# 1.8826047462703401

# %%
#original
Ry = 3.2898e15
n = 17
E = 321e6
delta = n - ( 1/ (np.sqrt( (E/Ry) + (1/n**2) )) )
print(delta)
delta12 = 0.00015307182760437854
delta11 = 0.00023968624945425177
deltaE = -Ry * ( 1/(n-delta12)**2 - 1/(n-delta11)**2)
print(deltaE*1e-6) #in MHz
# Out:
# 0.00023968624945425177
# 116.00000000168731

# %%
#Everything
x = []
y1 = [] 
y2 = []
ytot = []
e1 = []
e2 = []
y3 = []
z1 = [] 
z2 = []
g1 = []
g2 = []
z3 = []
v3 = []
w3 = []
h1 = []
h2 = []
i1 = []
i2 = []
scale1 = []
scale2 = []
scale3 = []
q = [] #quadrupole term

#Constants
pr4s = 13
pr5s = 6.64
pr3d = 5.10
pr4d = 14.48
pr6s = 0.487
pr5d = 1.130
Wp4s = 0.115
Wp5s = -0.123
Wp3d = 0.052
Wp4d = -0.144
Wp6s = -0.207
Wp5d = -0.217
D3d = 2.77e-4*(5/40)
D4d = 8.75e-5*(5/40)
D5d = 3.97e-5*(5/40)
#quadrupole term
D4p = 1.02e-3
Wp4p = -(2/3)*1.02e-3
pr24p = 21.73**2 

Ws4p = -0.115 
D4p = 1.02e-3 
sr4p = 13

e = 1.6e-19
epsilon0 = 8.85e-12
a0 = 5.292e-11
pi = 3.14159
hp = 6.626e-34
Theta = 1.289*e*a0**2
Wd4p = -0.053
Wd4f = -0.248
dr4p = 5.10
dr4f = 1.87

pas = 1
l = 7 # L'abscisse de départ est 7
for k in range(0, 25): 
    x.append(l)
    n = 45
    sc = 5e4/(l**3)
    scale1.append(sc)
    sc = 4e5/(l**5)
    scale2.append(sc)
    sc = 5e8/(l**14)
    scale3.append(sc)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    r4 = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    
    s = 6
    J = 0
    for gamma in range(0,int(6+1)):
        J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
        J = J + J0
    r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)
    
    #4p1/2
    W = 0
    K = l-1/2
    pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(2-l)*r6/Wp4s)
    pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(2-l)*r6/Wp5s)
    pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(2-l)*r6/Wp6s)
    pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) + (l+7)*r6/(9*Wp3d) - 2*r6*D3d*(l+7)/(15*Wp3d**2) )
    pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) + (l+7)*r6/(9*Wp4d) - 2*r6*D4d*(l+7)/(15*Wp4d**2) )
    pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) + (l+7)*r6/(9*Wp5d) - 2*r6*D5d*(l+7)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    pnlk_tot = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d + W
    pnlk = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d
    pnlkHz = pnlk*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    pnlk_totHz = pnlk_tot*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    qau = W #quadrupole term in atomic units
    qHz = qau*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    W = 0
    y1.append(np.absolute(pnlkHz)) 
    ytot.append(np.absolute(pnlk_totHz))
    q.append(np.absolute(qHz))
    
    K = l+1/2
    Pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(l+3)*r6/Wp4s)
    Pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(l+3)*r6/Wp5s)
    Pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(l+3)*r6/Wp6s)
    Pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) - (l-6)*r6/(9*Wp3d) + 2*r6*D3d*(l-6)/(15*Wp3d**2) )
    Pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) - (l-6)*r6/(9*Wp4d) + 2*r6*D4d*(l-6)/(15*Wp4d**2) )
    Pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) - (l-6)*r6/(9*Wp5d) + 2*r6*D5d*(l-6)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    Pnlk = Pnlk4s + Pnlk5s + Pnlk3d + Pnlk4d + Pnlk6s + Pnlk5d + W
    PnlkHz = Pnlk*(4.360e-18)*10**(-6)/(6.626e-34)
    W = 0
    #z1.append(PnlkHz)
    z1.append(np.absolute(PnlkHz))
    
    #4s1/2
    pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p - 2*(l+1)*D4p*r6/(9*Ws4p**2) ) #K=l-1/2
    pnlkHzs = pnlks*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y2.append(pnlkHzs)
    
    Pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p + 2*l*D4p*r6/(9*Ws4p**2) ) #K=l+1/2
    PnlkHzs = Pnlks*(4.360e-18)*10**(-6)/(6.626e-34)
    z2.append(PnlkHzs)
    
    #3d3/2
    #first order
    K = l-1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    e1.append(frequency)
    
    K = l+1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    g1.append(frequency)
    
    K = l+3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    h1.append(frequency)
    
    K = l-3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    i1.append(frequency)
    #second order
    pnlk4p = (dr4p/Wd4p)*( r4*(13*l+4)/75 + 6*(-l**2+2*l+1)*r6/(25*Wd4p) - D4p*(4*l+7)*r4/(75*Wd4p) +4*r6*D4p*(16*l**2-7*l-41)/(225*Wd4p**2) )/(2*l-1)
    pnlk4pHz = (pnlk4p)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l-1)/(25*(2*l-1)) )
    pnlk4fHz = (pnlk4f)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlkHzd = pnlk4pHz + pnlk4fHz #put in MHz
    e2.append(pnlkHzd)
    
    Pnlk4p = (dr4p/Wd4p)*( r4*(13*l+9)/75 + 6*(l**2+4*l+2)*r6/(25*Wd4p) - D4p*(4*l-3)*r4/(75*Wd4p) + (4*D4p*(-16*l**2-39*l+18)*r6)/(225*Wd4p**2) )/(2*l+3)
    Pnlk4pHz = Pnlk4p*(4.360e-18)*10**(-6)/(6.626e-34)
    Pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l+4)/(25*(2*l+3)) )
    Pnlk4fHz = Pnlk4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlkHzd = Pnlk4pHz + Pnlk4fHz
    g2.append(PnlkHzd)
    
    PnlK4p = (dr4p/Wd4p)*( r4*(9*l+10)/25 + 2*(9*l+10)*(l+3)*r6/(25*Wd4p) - (16*l+15)*r4*D4p/(75*Wd4p) - 4*(16*l+15)*(l+3)*r6*D4p/(75*Wd4p**2) )/(2*l+3)
    PnlK4pHz = PnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlK4f = (dr4f*r4/Wd4f)*( (11*l+15)/(25*(2*l+3)) )
    PnlK4fHz = PnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlKHzd = PnlK4pHz + PnlK4fHz
    h2.append(PnlKHzd)
    
    pnlK4p = (dr4p/Wd4p)*( r4*(9*l-1)/25 + 2*(9*l-1)*(2-l)*r6/(25*Wd4p) - (16*l+1)*D4p*r4/(75*Wd4p) - 4*(16*l+1)*(2-l)*r6*D4p/(75*Wd4p**2) )/(2*l-1)
    pnlK4pHz = pnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlK4f = (dr4f*r4/Wd4f)*( (11*l-4)/(25*(2*l-1)) )
    pnlK4fHz = pnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlKHzd = pnlK4pHz + pnlK4fHz
    i2.append(pnlKHzd)
    
    l += pas

y3 = np.add(e1,e2)
z3 = np.add(g1,g2)
v3 = np.add(h1,h2)
w3 = np.add(i1,i2)
y1 = np.array(y1)
y2 = np.array(y2)
y3 = np.array(y3)
z1 = np.array(z1)
z2 = np.array(z2)
z3 = np.array(z3)
v3 = np.array(v3)
w3 = np.array(w3)

#K splittings


y3 = np.array(y3) #positive argument for log
y3 = -y3  
y2 = np.array(y2) #positive argument for log
y2 = -y2

z3 = np.array(z3) #positive argument for log
z3 = -z3  
z2 = np.array(z2) #positive argument for log
z2 = -z2

plt.figure()
#plt.scatter(x,y2,label='4s1/2',color='b')
plt.scatter(x,y1,label='|dipole order|',color='purple')
#plt.scatter(x,y3,label='3d3/2',color='olive')
#plt.scatter(x,z2,label='4s1/2',marker='x',color='b')
#plt.scatter(x,z1,label='4p1/2',marker='x',color='purple')
#plt.scatter(x,z3,label='3d3/2',marker='x',color='olive')
#plt.scatter(x,v3,label='3d3/2',marker='+',color='olive')
#plt.scatter(x,w3,label='3d3/2',marker='v',color='olive')
plt.scatter(x,q,label='|quadrupole order|',color='olive')
plt.scatter(x,ytot,label='|total|')
#plt.plot(x,scale1,color='k') #,label='l^-3'
#plt.plot(x,scale2,color='cyan') #,label='l^-5'
#plt.plot(x,scale3,color='purple')
plt.semilogy()

plt.legend()

#plt.title('Contributions of the dipole and quadrupole orders to the \n total energy shift for the (4p1/2)45l2 states, in absolute value') #K=l-1/2 in dots and K=l+1/2 in plus
plt.xlabel('Orbital quantum number l2')
plt.ylabel('Energy shift [MHz]')
plt.savefig('dipole_quadrupole.png')

# %%
#Everything
x = []
y1 = [] 
y2 = []
ytot = []
e1 = []
e2 = []
y3 = []
z1 = [] 
z2 = []
g1 = []
g2 = []
z3 = []
v3 = []
w3 = []
h1 = []
h2 = []
i1 = []
i2 = []
scale1 = []
scale2 = []
scale3 = []
q = [] #quadrupole term

#Constants
pr4s = 13
pr5s = 6.64
pr3d = 5.10
pr4d = 14.48
pr6s = 0.487
pr5d = 1.130
Wp4s = 0.115
Wp5s = -0.123
Wp3d = 0.052
Wp4d = -0.144
Wp6s = -0.207
Wp5d = -0.217
D3d = 2.77e-4*(5/40)
D4d = 8.75e-5*(5/40)
D5d = 3.97e-5*(5/40)
#quadrupole term
D4p = 1.02e-3
Wp4p = -(2/3)*1.02e-3
pr24p = 21.73**2 

Ws4p = -0.115 
D4p = 1.02e-3 
sr4p = 13

e = 1.6e-19
epsilon0 = 8.85e-12
a0 = 5.292e-11
pi = 3.14159
hp = 6.626e-34
Theta = 1.289*e*a0**2
Wd4p = -0.053
Wd4f = -0.248
dr4p = 5.10
dr4f = 1.87

pas = 1
n = 30 # L'abscisse de départ est 7
for k in range(0, 31): 
    x.append(n)
    l = 12
    sc = 5e4/(l**3)
    scale1.append(sc)
    sc = 4e5/(l**5)
    scale2.append(sc)
    sc = 5e8/(l**14)
    scale3.append(sc)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    r4 = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    
    s = 6
    J = 0
    for gamma in range(0,int(6+1)):
        J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
        J = J + J0
    r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)
    
    #4p1/2
    W = 0
    K = l-1/2
    pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(2-l)*r6/Wp4s)
    pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(2-l)*r6/Wp5s)
    pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(2-l)*r6/Wp6s)
    pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) + (l+7)*r6/(9*Wp3d) - 2*r6*D3d*(l+7)/(15*Wp3d**2) )
    pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) + (l+7)*r6/(9*Wp4d) - 2*r6*D4d*(l+7)/(15*Wp4d**2) )
    pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) + (l+7)*r6/(9*Wp5d) - 2*r6*D5d*(l+7)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    pnlk_tot = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d + W
    pnlk = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d
    pnlkHz = pnlk*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    pnlk_totHz = pnlk_tot*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    qau = W #quadrupole term in atomic units
    qHz = qau*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    W = 0
    y1.append(np.absolute(pnlkHz)) 
    ytot.append(np.absolute(pnlk_totHz))
    q.append(np.absolute(qHz))
    
    K = l+1/2
    Pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(l+3)*r6/Wp4s)
    Pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(l+3)*r6/Wp5s)
    Pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(l+3)*r6/Wp6s)
    Pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) - (l-6)*r6/(9*Wp3d) + 2*r6*D3d*(l-6)/(15*Wp3d**2) )
    Pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) - (l-6)*r6/(9*Wp4d) + 2*r6*D4d*(l-6)/(15*Wp4d**2) )
    Pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) - (l-6)*r6/(9*Wp5d) + 2*r6*D5d*(l-6)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    Pnlk = Pnlk4s + Pnlk5s + Pnlk3d + Pnlk4d + Pnlk6s + Pnlk5d + W
    PnlkHz = Pnlk*(4.360e-18)*10**(-6)/(6.626e-34)
    W = 0
    #z1.append(PnlkHz)
    z1.append(np.absolute(PnlkHz))
    
    #4s1/2
    pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p - 2*(l+1)*D4p*r6/(9*Ws4p**2) ) #K=l-1/2
    pnlkHzs = pnlks*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y2.append(pnlkHzs)
    
    Pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p + 2*l*D4p*r6/(9*Ws4p**2) ) #K=l+1/2
    PnlkHzs = Pnlks*(4.360e-18)*10**(-6)/(6.626e-34)
    z2.append(PnlkHzs)
    
    #3d3/2
    #first order
    K = l-1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    e1.append(frequency)
    
    K = l+1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    g1.append(frequency)
    
    K = l+3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    h1.append(frequency)
    
    K = l-3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    i1.append(frequency)
    #second order
    pnlk4p = (dr4p/Wd4p)*( r4*(13*l+4)/75 + 6*(-l**2+2*l+1)*r6/(25*Wd4p) - D4p*(4*l+7)*r4/(75*Wd4p) +4*r6*D4p*(16*l**2-7*l-41)/(225*Wd4p**2) )/(2*l-1)
    pnlk4pHz = (pnlk4p)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l-1)/(25*(2*l-1)) )
    pnlk4fHz = (pnlk4f)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlkHzd = pnlk4pHz + pnlk4fHz #put in MHz
    e2.append(pnlkHzd)
    
    Pnlk4p = (dr4p/Wd4p)*( r4*(13*l+9)/75 + 6*(l**2+4*l+2)*r6/(25*Wd4p) - D4p*(4*l-3)*r4/(75*Wd4p) + (4*D4p*(-16*l**2-39*l+18)*r6)/(225*Wd4p**2) )/(2*l+3)
    Pnlk4pHz = Pnlk4p*(4.360e-18)*10**(-6)/(6.626e-34)
    Pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l+4)/(25*(2*l+3)) )
    Pnlk4fHz = Pnlk4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlkHzd = Pnlk4pHz + Pnlk4fHz
    g2.append(PnlkHzd)
    
    PnlK4p = (dr4p/Wd4p)*( r4*(9*l+10)/25 + 2*(9*l+10)*(l+3)*r6/(25*Wd4p) - (16*l+15)*r4*D4p/(75*Wd4p) - 4*(16*l+15)*(l+3)*r6*D4p/(75*Wd4p**2) )/(2*l+3)
    PnlK4pHz = PnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlK4f = (dr4f*r4/Wd4f)*( (11*l+15)/(25*(2*l+3)) )
    PnlK4fHz = PnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlKHzd = PnlK4pHz + PnlK4fHz
    h2.append(PnlKHzd)
    
    pnlK4p = (dr4p/Wd4p)*( r4*(9*l-1)/25 + 2*(9*l-1)*(2-l)*r6/(25*Wd4p) - (16*l+1)*D4p*r4/(75*Wd4p) - 4*(16*l+1)*(2-l)*r6*D4p/(75*Wd4p**2) )/(2*l-1)
    pnlK4pHz = pnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlK4f = (dr4f*r4/Wd4f)*( (11*l-4)/(25*(2*l-1)) )
    pnlK4fHz = pnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlKHzd = pnlK4pHz + pnlK4fHz
    i2.append(pnlKHzd)
    
    n += pas

y3 = np.add(e1,e2)
z3 = np.add(g1,g2)
v3 = np.add(h1,h2)
w3 = np.add(i1,i2)
y1 = np.array(y1)
y2 = np.array(y2)
y3 = np.array(y3)
z1 = np.array(z1)
z2 = np.array(z2)
z3 = np.array(z3)
v3 = np.array(v3)
w3 = np.array(w3)

#K splittings


y3 = np.array(y3) #positive argument for log
y3 = -y3  
y2 = np.array(y2) #positive argument for log
y2 = -y2

z3 = np.array(z3) #positive argument for log
z3 = -z3  
z2 = np.array(z2) #positive argument for log
z2 = -z2

plt.figure()
#plt.scatter(x,y2,label='4s1/2',color='b')
plt.scatter(x,y1,label='|dipole order|',color='purple')
#plt.scatter(x,y3,label='3d3/2',color='olive')
#plt.scatter(x,z2,label='4s1/2',marker='x',color='b')
#plt.scatter(x,z1,label='4p1/2',marker='x',color='purple')
#plt.scatter(x,z3,label='3d3/2',marker='x',color='olive')
#plt.scatter(x,v3,label='3d3/2',marker='+',color='olive')
#plt.scatter(x,w3,label='3d3/2',marker='v',color='olive')
plt.scatter(x,q,label='|quadrupole order|',color='olive')
plt.scatter(x,ytot,label='|total|')
#plt.plot(x,scale1,color='k') #,label='l^-3'
#plt.plot(x,scale2,color='cyan') #,label='l^-5'
#plt.plot(x,scale3,color='purple')
#plt.semilogy()

plt.legend()

#plt.title('Contributions of the dipole and quadrupole orders to the \n total energy shift for the (4p1/2)n212 states, in absolute value') #K=l-1/2 in dots and K=l+1/2 in plus
plt.xlabel('Orbital quantum number l2')
plt.ylabel('Energy shift [MHz]')
plt.savefig('dipole_quadrupole_n.png')

# %%
x = []
y1 = [] 
y2 = []
e1 = []
e2 = []
y3 = []
z1 = [] 
z2 = []
g1 = []
g2 = []
z3 = []
v3 = []
w3 = []
h1 = []
h2 = []
i1 = []
i2 = []
scale = [] #To find a scaling law

pas = 1
n = 30 # L'abscisse de départ est 30
for k in range(0, 31): # On veut les points de 30 à 60
    x.append(n)
    l = 12
    sc = 5e4/(n**3)
    scale.append(sc)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    r4 = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    
    s = 6
    J = 0
    for gamma in range(0,int(6+1)):
        J0=(-1)**(s-gamma)*(scipy.special.binom(s,gamma)*scipy.special.binom(n-l-1+gamma,s)/scipy.special.binom(2*l+1+s-gamma,s+1))
        J = J + J0
    r8 = (2/n)**8*(1/(2*n))*J/math.factorial(s+1)
    
    #4p1/2
    W = 0
    K = l-1/2
    pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(2-l)*r6/Wp4s)
    pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(2-l)*r6/Wp5s)
    pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(2-l)*r6/Wp6s)
    pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) + (l+7)*r6/(9*Wp3d) - 2*r6*D3d*(l+7)/(15*Wp3d**2) )
    pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) + (l+7)*r6/(9*Wp4d) - 2*r6*D4d*(l+7)/(15*Wp4d**2) )
    pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) + (l+7)*r6/(9*Wp5d) - 2*r6*D5d*(l+7)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    pnlk = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d + W
    pnlkHz = pnlk*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y1.append(pnlkHz) 
    
    W = 0
    K = l+1/2
    Pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(l+3)*r6/Wp4s)
    Pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(l+3)*r6/Wp5s)
    Pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(l+3)*r6/Wp6s)
    Pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) - (l-6)*r6/(9*Wp3d) + 2*r6*D3d*(l-6)/(15*Wp3d**2) )
    Pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) - (l-6)*r6/(9*Wp4d) + 2*r6*D4d*(l-6)/(15*Wp4d**2) )
    Pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) - (l-6)*r6/(9*Wp5d) + 2*r6*D5d*(l-6)/(15*Wp5d**2) )
    for lp in range (int(l-2),int(l+3),2):
        Wbar = (1/2)*(9-l*(l+1)+lp*(lp+1))
        C2 = 3*3*2*4*(2*l+1)*(2*lp+1)*(Wigner.Wigner6j(1/2,1,1/2,2,3/2,1)*Wigner.Wigner6j(K,l,1/2,2,3/2,lp)*Wigner.Wigner3j(1,2,1,0,0,0)*Wigner.Wigner3j(l,2,lp,0,0,0))**2
        W = W +(pr24p*r6/Wp4p)*(C2 +(D4p*(1/3)*C2)/Wp4p + Wbar*C2*r8/(r6*Wp4p) + 2*Wbar*C2*D4p*(1/3)*r8/(r6*Wp4p**2))
    Pnlk = Pnlk4s + Pnlk5s + Pnlk3d + Pnlk4d + Pnlk6s + Pnlk5d + W
    PnlkHz = Pnlk*(4.360e-18)*10**(-6)/(6.626e-34)
    z1.append(PnlkHz)
    
    #4s1/2
    pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p - 2*(l+1)*D4p*r6/(9*Ws4p**2) ) #K=l-1/2
    pnlkHzs = pnlks*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y2.append(pnlkHzs)
    
    Pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p + 2*l*D4p*r6/(9*Ws4p**2) ) #K=l+1/2
    PnlkHzs = Pnlks*(4.360e-18)*10**(-6)/(6.626e-34)
    z2.append(PnlkHzs)
    
    #3d3/2
    #first order
    K = l-1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    e1.append(frequency)
    
    K = l+1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    g1.append(frequency)
    
    K = l+3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    h1.append(frequency)
    
    K = l-3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    i1.append(frequency)
    #second order
    pnlk4p = (dr4p/Wd4p)*( r4*(13*l+4)/75 + 6*(-l**2+2*l+1)*r6/(25*Wd4p) - D4p*(4*l+7)*r4/(75*Wd4p) +4*r6*D4p*(16*l**2-7*l-41)/(225*Wd4p**2) )/(2*l-1)
    pnlk4pHz = (pnlk4p)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l-1)/(25*(2*l-1)) )
    pnlk4fHz = (pnlk4f)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlkHzd = pnlk4pHz + pnlk4fHz #put in MHz
    e2.append(pnlkHzd)
    
    Pnlk4p = (dr4p/Wd4p)*( r4*(13*l+9)/75 + 6*(l**2+4*l+2)*r6/(25*Wd4p) - D4p*(4*l-3)*r4/(75*Wd4p) + (4*D4p*(-16*l**2-39*l+18)*r6)/(225*Wd4p**2) )/(2*l+3)
    Pnlk4pHz = Pnlk4p*(4.360e-18)*10**(-6)/(6.626e-34)
    Pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l+4)/(25*(2*l+3)) )
    Pnlk4fHz = Pnlk4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlkHzd = Pnlk4pHz + Pnlk4fHz
    g2.append(PnlkHzd)
    
    PnlK4p = (dr4p/Wd4p)*( r4*(9*l+10)/25 + 2*(9*l+10)*(l+3)*r6/(25*Wd4p) - (16*l+15)*r4*D4p/(75*Wd4p) - 4*(16*l+15)*(l+3)*r6*D4p/(75*Wd4p**2) )/(2*l+3)
    PnlK4pHz = PnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlK4f = (dr4f*r4/Wd4f)*( (11*l+15)/(25*(2*l+3)) )
    PnlK4fHz = PnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlKHzd = PnlK4pHz + PnlK4fHz
    h2.append(PnlKHzd)
    
    pnlK4p = (dr4p/Wd4p)*( r4*(9*l-1)/25 + 2*(9*l-1)*(2-l)*r6/(25*Wd4p) - (16*l+1)*D4p*r4/(75*Wd4p) - 4*(16*l+1)*(2-l)*r6*D4p/(75*Wd4p**2) )/(2*l-1)
    pnlK4pHz = pnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlK4f = (dr4f*r4/Wd4f)*( (11*l-4)/(25*(2*l-1)) )
    pnlK4fHz = pnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlKHzd = pnlK4pHz + pnlK4fHz
    i2.append(pnlKHzd)
    
    n += pas

y3 = np.add(e1,e2)
z3 = np.add(g1,g2)
v3 = np.add(h1,h2)
w3 = np.add(i1,i2)
print(y3,z3,v3,w3)
y3 = np.array(y3) #positive argument for log
y3 = -y3  
y2 = np.array(y2) #positive argument for log
y2 = -y2

y1 = np.array(y1)
y2 = np.array(y2)
y3 = np.array(y3)
z1 = np.array(z1)
z2 = np.array(z2)
z3 = np.array(z3)
v3 = np.array(v3)
w3 = np.array(w3)
z3 = np.array(z3) #positive argument for log
z3 = -z3  
z2 = np.array(z2) #positive argument for log
z2 = -z2

plt.figure()
plt.scatter(x,y2,label='4s1/2',color='b')
plt.scatter(x,y1,label='4p1/2',color='purple')
plt.scatter(x,y3,label='3d3/2',color='olive')
plt.scatter(x,z2,label='4s1/2',marker='x',color='b')
plt.scatter(x,z1,label='4p1/2',marker='x',color='purple')
plt.scatter(x,z3,label='3d3/2',marker='x',color='olive')
plt.scatter(x,v3,label='3d3/2',marker='+',color='olive')
plt.scatter(x,w3,label='3d3/2',marker='v',color='olive')
plt.plot(x,scale,color='k',label='n^-3')
plt.semilogy()

#plt.legend()
#plt.title('Total energy shift, in absolute value, with respect to \n the principal quantum number n2 (l2=12)') # K=l-1/2 in dots and K=l+1/2 in plus
plt.xlabel('Principal quantum number n2')
plt.ylabel('Energy shift [MHz]')
plt.savefig('total_energy_shift_n.png')
# Out:
# [-81.96404563 -74.3296038  -67.61337932 -61.68154634 -56.42299041
#  -51.74494123 -47.5695383  -43.83111139 -40.47401293 -37.45087945
#  -34.72122906 -32.25032363 -30.00824079 -27.9691133  -26.11050257
#  -24.41288034 -22.85919789 -21.43452665 -20.12575701 -18.9213451
#  -17.81109898 -16.78599759 -15.83803685 -14.96009844 -14.14583758
#  -13.38958674 -12.68627283 -12.03134575 -11.42071656 -10.8507039
#  -10.31798736] [-99.37164263 -90.09498185 -81.93706395 -74.73432908 -68.35107235
#  -62.67406672 -57.60833935 -53.07383064 -49.00273371 -45.33736255
#  -42.02843344 -39.03367189 -36.31667717 -33.84599227 -31.59433831
#  -29.53798143 -27.656207   -25.93088098 -24.34608271 -22.88779609
#  -21.5436491  -20.30269319 -19.15521587 -18.092581   -17.10709217
#  -16.19187556 -15.34077923 -14.54828619 -13.80943928 -13.119776
#  -12.47527189] [51.4584324  46.57464808 42.29145756 38.51908314 35.18341631 32.22291158
#  29.58616575 27.23001685 25.11804025 23.219351   21.50764366 19.96041815
# ...

# %%
#Everything: Knl
x = []
y1 = [] 
y2 = []
e1 = []
e2 = []
y3 = []
z1 = [] 
z2 = []
g1 = []
g2 = []
z3 = []
v3 = []
w3 = []
h1 = []
h2 = []
i1 = []
i2 = []
scale1 = []
scale2 = []

pas = 1
l = 8 # L'abscisse de départ est 7
for k in range(0, 25): 
    x.append(l)
    n = 45
    sc = 7e4/(l**3)
    scale1.append(sc)
    sc = 6e5/(l**8)
    scale2.append(sc)
    r6 = (35*n**4-5*n**2*(6*l*(l+1)-5)+3*(l+2)*(l+1)*l*(l-1))/(8*n**7*(l+2.5)*(l+2)*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5)*(l-1)*(l-1.5))
    r4 = (3*n**2-l*(l+1))/(2*n**5*(l+1.5)*(l+1)*(l+0.5)*l*(l-0.5))
    
    #4p1/2
    pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(2-l)*r6/Wp4s)
    pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(2-l)*r6/Wp5s)
    pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(2-l)*r6/Wp6s)
    pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) + (l+7)*r6/(9*Wp3d) - 2*r6*D3d*(l+7)/(15*Wp3d**2) )
    pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) + (l+7)*r6/(9*Wp4d) - 2*r6*D4d*(l+7)/(15*Wp4d**2) )
    pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) + (l+7)*r6/(9*Wp5d) - 2*r6*D5d*(l+7)/(15*Wp5d**2) )
    pnlk = pnlk4s + pnlk5s + pnlk3d + pnlk4d + pnlk6s + pnlk5d
    pnlkHz = pnlk*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y1.append(pnlkHz) 
    
    Pnlk4s = (pr4s/Wp4s)*(r4/9 + (1/9)*(l+3)*r6/Wp4s)
    Pnlk5s = (pr5s/Wp5s)*(r4/9 + (1/9)*(l+3)*r6/Wp5s)
    Pnlk6s = (pr6s/Wp6s)*(r4/9 + (1/9)*(l+3)*r6/Wp6s)
    Pnlk3d = (pr3d/Wp3d)*(2*r4/9 - 2*r4*D3d/(15*Wp3d) - (l-6)*r6/(9*Wp3d) + 2*r6*D3d*(l-6)/(15*Wp3d**2) )
    Pnlk4d = (pr4d/Wp4d)*(2*r4/9 - 2*r4*D4d/(15*Wp4d) - (l-6)*r6/(9*Wp4d) + 2*r6*D4d*(l-6)/(15*Wp4d**2) )
    Pnlk5d = (pr5d/Wp5d)*(2*r4/9 - 2*r4*D5d/(15*Wp5d) - (l-6)*r6/(9*Wp5d) + 2*r6*D5d*(l-6)/(15*Wp5d**2) )
    Pnlk = Pnlk4s + Pnlk5s + Pnlk3d + Pnlk4d + Pnlk6s + Pnlk5d
    PnlkHz = Pnlk*(4.360e-18)*10**(-6)/(6.626e-34)
    z1.append(PnlkHz)
    
    #4s1/2
    pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p - 2*(l+1)*D4p*r6/(9*Ws4p**2) ) #K=l-1/2
    pnlkHzs = pnlks*(4.360e-18)*10**(-6)/(6.626e-34) #put in MHz
    y2.append(pnlkHzs)
    
    Pnlks = (sr4p/Ws4p)*( r4/3 + r6/Ws4p + 2*l*D4p*r6/(9*Ws4p**2) ) #K=l+1/2
    PnlkHzs = Pnlks*(4.360e-18)*10**(-6)/(6.626e-34)
    z2.append(PnlkHzs)
    
    #3d3/2
    #first order
    K = l-1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    e1.append(frequency)
    
    K = l+1/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    g1.append(frequency)
    
    K = l+3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    h1.append(frequency)
    
    K = l-3/2
    j1 = 3/2 
    h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
    f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
    DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
    frequency = DeltaE*10**(-6)/hp #put in MHz
    i1.append(frequency)
    #second order
    K = l -1/2
    pnlk4p = (dr4p/Wd4p)*( r4*(13*l+4)/75 + 6*(-l**2+2*l+1)*r6/(25*Wd4p) - D4p*(4*l+7)*r4/(75*Wd4p) +4*r6*D4p*(16*l**2-7*l-41)/(225*Wd4p**2) )/(2*l-1)
    pnlk4pHz = (pnlk4p)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l-1)/(25*(2*l-1)) ) #+ (dr4f*r6/Wd4f**2)*(7*5*4*6*l)*Wigner.Wigner6j(1/2,2,3/2,1,5/2,3)**2*Wigner.Wigner3j(2,1,3,0,0,0)**2*(2*(l+3)*(2*l+3)*Wigner.Wigner6j(K,l,3/2,1,5/2,l+1)**2*Wigner.Wigner3j(l,1,l+1,0,0,0)**2+2*(2-l)*(2*l-1)*Wigner.Wigner6j(K,l,3/2,1,5/2,l-1)**2*Wigner.Wigner3j(l,1,l-1,0,0,0)**2)
    pnlk4fHz = (pnlk4f)*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlkHzd = pnlk4pHz + pnlk4fHz #put in MHz
    e2.append(pnlkHzd)
    
    Pnlk4p = (dr4p/Wd4p)*( r4*(13*l+9)/75 + 6*(l**2+4*l+2)*r6/(25*Wd4p) - D4p*(4*l-3)*r4/(75*Wd4p) + (4*D4p*(-16*l**2-39*l+18)*r6)/(225*Wd4p**2) )/(2*l+3)
    Pnlk4pHz = Pnlk4p*(4.360e-18)*10**(-6)/(6.626e-34)
    Pnlk4f = (dr4f*r4/Wd4f)*( 3*(3*l+4)/(25*(2*l+3)) )#+ (dr4f*r6/Wd4f**2)*(7*5*4*6*l)*Wigner.Wigner6j(1/2,2,3/2,1,5/2,3)**2*Wigner.Wigner3j(2,1,3,0,0,0)**2*(2*(l+3)*(2*l+3)*Wigner.Wigner6j(K,l,3/2,1,5/2,l+1)**2*Wigner.Wigner3j(l,1,l+1,0,0,0)**2+2*(2-l)*(2*l-1)*Wigner.Wigner6j(K,l,3/2,1,5/2,l-1)**2*Wigner.Wigner3j(l,1,l-1,0,0,0)**2)
    Pnlk4fHz = Pnlk4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlkHzd = Pnlk4pHz + Pnlk4fHz
    g2.append(PnlkHzd)
    
    K=l+3/2
    PnlK4p = (dr4p/Wd4p)*( r4*(9*l+10)/25 + 2*(9*l+10)*(l+3)*r6/(25*Wd4p) - (16*l+15)*r4*D4p/(75*Wd4p) - 4*(16*l+15)*(l+3)*r6*D4p/(75*Wd4p**2) )/(2*l+3)
    PnlK4pHz = PnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlK4f = (dr4f*r4/Wd4f)*( (11*l+15)/(25*(2*l+3)) )#+ (dr4f*r6/Wd4f**2)*(7*5*4*6*l)*Wigner.Wigner6j(1/2,2,3/2,1,5/2,3)**2*Wigner.Wigner3j(2,1,3,0,0,0)**2*(2*(l+3)*(2*l+3)*Wigner.Wigner6j(K,l,3/2,1,5/2,l+1)**2*Wigner.Wigner3j(l,1,l+1,0,0,0)**2+2*(2-l)*(2*l-1)*Wigner.Wigner6j(K,l,3/2,1,5/2,l-1)**2*Wigner.Wigner3j(l,1,l-1,0,0,0)**2)
    PnlK4fHz = PnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    PnlKHzd = PnlK4pHz + PnlK4fHz
    h2.append(PnlKHzd)
    
    pnlK4p = (dr4p/Wd4p)*( r4*(9*l-1)/25 + 2*(9*l-1)*(2-l)*r6/(25*Wd4p) - (16*l+1)*D4p*r4/(75*Wd4p) - 4*(16*l+1)*(2-l)*r6*D4p/(75*Wd4p**2) )/(2*l-1)
    pnlK4pHz = pnlK4p*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlK4f = (dr4f*r4/Wd4f)*( (11*l-4)/(25*(2*l-1)) )
    pnlK4fHz = pnlK4f*(4.360e-18)*10**(-6)/(6.626e-34)
    pnlKHzd = pnlK4pHz + pnlK4fHz
    i2.append(pnlKHzd)
    
    l += pas

y3 = np.add(e1,e2)
z3 = np.add(g1,g2)
v3 = np.add(h1,h2)
w3 = np.add(i1,i2)
#print(e2,h2)
print(y3,z3,v3,w3)
y1 = np.array(y1)
y2 = np.array(y2)
y3 = np.array(y3)
z1 = np.array(z1)
z2 = np.array(z2)
z3 = np.array(z3)
v3 = np.array(v3)
w3 = np.array(w3)

#K splittings
k3 = y3-z3
k2 = y2-z2
k1 = y1-z1
k4 = w3-v3
k5 = -y3 + v3

#y3 = np.array(y3) #positive argument for log
#y3 = -y3  
#y2 = np.array(y2) #positive argument for log
#y2 = -y2

#z3 = np.array(z3) #positive argument for log
#z3 = -z3  
#z2 = np.array(z2) #positive argument for log
#z2 = -z2

plt.figure()

plt.scatter(x,k2,label='4s1/2',color='b')
plt.scatter(x,k1,label='4p1/2',color='purple')
plt.scatter(x,k3,label='3d3/2;1/2,-1/2',color='orange')
plt.scatter(x,k4,label='3d3/2;3/2,-3/2',color='brown')
plt.scatter(x,k5,label='3d3/2;milieu',color='olive')
plt.plot(x,scale1,color='k',label='l^-3')
plt.plot(x,scale2,color='r',label='l^-8')
plt.semilogy()

#plt.legend()
#plt.title('K splittings with respect to the orbital quantum \n number l2 (n2=45)')
plt.xlabel('Orbital quantum number l2')
plt.ylabel('K splitting [MHz]')
plt.savefig('Ksplitting.png')
# Out:
# [-88.99570859 -60.37127606 -43.08153172 -31.94621305 -24.41288034
#  -19.11436425 -15.26849122 -12.40336607 -10.22159594  -8.52880724
#   -7.193975    -6.12640418  -5.26185454  -4.55389662  -3.96836961
#   -3.47973665  -3.0686335   -2.72018625  -2.42283587  -2.16750322
#   -1.94698708  -1.75552428  -1.58846416  -1.44202493  -1.31310937] [-106.57130041  -73.42785956  -52.56792666  -38.87252918  -29.53798143
#   -22.96658053  -18.20988455  -14.68310276  -12.01316887   -9.95477154
#    -8.34221699   -7.06088799   -6.02979587   -5.19061476   -4.50061521
#    -3.92800636   -3.44880203   -3.04467234   -2.70144556   -2.40804703
#    -2.15573668   -1.93755393   -1.74790851   -1.58227545   -1.43696531] [29.01337382 24.72509275 21.05818252 17.83254635 15.06741217 12.74536276
#  10.8167912   9.22177104  7.90259593  6.80879104  5.89822938  5.13657829
#   4.49618163  3.95486806  3.49487684  3.10195653  2.76463543  2.47364201
# ...

# %%
print(Wigner.Wigner6j(1/2,l,3/2,1,5/2,l+1))
# Out:
# 0

# %%
#Check of the first order energy shift formula for the paper 
#Formula Master's thesis:
l = 12
n = 55
K = l-1/2
j1 = 3/2 
h = (1/2)*(K*(K+1)-j1*(j1+1)-l*(l+1))
f2 = -(6*(h**2)+3*h-2*j1*(j1+1)*l*(l+1))/(4*j1*(j1+1)*(2*l-1)*(2*l+3))
DeltaE = -(e/(4*pi*epsilon0*a0**3))*(4*(j1+1)*Theta*f2)/((2*j1-1)*(n**3)*l*(l+0.5)*(l+1)) 
frequency = DeltaE*10**(-6)/hp #put in MHz

#Formula paper ralc
theta = 1.289

r2 = 1/(n**3*l*(l+1/2)*(l+1))
deltaE = r2*(2*l+1)*2*np.sqrt(5)*(-1)**(K+j1-1)*theta*Wigner.Wigner6j(K,l,j1,2,j1,l)*Wigner.Wigner3j(l,2,l,0,0,0)
f = deltaE*10**(-6)*6579683920502000.0 #put in MHz

print(frequency,f)
#print(Wigner.Wigner6j(K,l,j1,2,j1,l),Wigner.Wigner3j(l,2,l,0,0,0),(-1)**(K+j1))
# Out:
# -11.340137798006692 -11.365994267261454

# %%
theta_cal = (-1)**(1+2*2+1/2+j1)*(2*j1+1)*(2*2+1)*Wigner.Wigner3j(2,2,2,0,0,0)*Wigner.Wigner6j(3/2,2,1/2,2,3/2,2)*Wigner.Wigner3j(3/2,2,3/2,-3/2,0,3/2)
print(theta_cal)
# Out:
# 0.19999999999999996

# %%
 #deltaE(1) sign
d = (-1.)**(K+1/2)*Wigner.Wigner3j(2,2,2,0,0,0)*Wigner.Wigner3j(l,2,l,0,0,0)*Wigner.Wigner6j(j1,2,j1,2,1/2,2)*Wigner.Wigner6j(j1,l,K,l,j1,2)
print(d)
# Out:
# 0.0001739130434782609
